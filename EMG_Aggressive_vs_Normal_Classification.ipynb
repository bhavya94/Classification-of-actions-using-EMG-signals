# %% [markdown]
# ## Normal vs. Aggressive NOTEBOOK FOR ALL SUBJECTS

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline  
from tsfresh import extract_features, extract_relevant_features, select_features
from tsfresh.utilities.dataframe_functions import impute
from tsfresh.feature_extraction import ComprehensiveFCParameters, MinimalFCParameters, EfficientFCParameters
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve
from sklearn import preprocessing
import sklearn.metrics as metrics
import numpy as np
import copy
# Out:
# C:\Users\Bhavya\Anaconda3\envs\AppliedDataScience\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ### Importing Feature Dataframes

# %%
sub1_bowing_features = pd.read_csv('sub1_Bowing_processed_features.csv')
sub2_bowing_features = pd.read_csv('sub2_Bowing_processed_features.csv')
sub3_bowing_features = pd.read_csv('sub3_Bowing_processed_features.csv')
sub4_bowing_features = pd.read_csv('sub4_Bowing_processed_features.csv')

sub1_clapping_features = pd.read_csv('sub1_Clapping_processed_features.csv')
sub2_clapping_features = pd.read_csv('sub2_Clapping_processed_features.csv')
sub3_clapping_features = pd.read_csv('sub3_Clapping_processed_features.csv')
sub4_clapping_features = pd.read_csv('sub4_Clapping_processed_features.csv')

sub1_handshaking_features = pd.read_csv('sub1_handshake_processed_features.csv')
sub2_handshaking_features = pd.read_csv('sub2_handshake_processed_features.csv')
sub3_handshaking_features = pd.read_csv('sub3_handshake_processed_features.csv')
sub4_handshaking_features = pd.read_csv('sub4_handshake_processed_features.csv')

sub1_hugging_features = pd.read_csv('sub1_Hugging_processed_features.csv')
sub2_hugging_features = pd.read_csv('sub2_Hugging_processed_features.csv')
sub3_hugging_features = pd.read_csv('sub3_Hugging_processed_features.csv')
sub4_hugging_features = pd.read_csv('sub4_Hugging_processed_features.csv')

sub1_jumping_features = pd.read_csv('sub1_jumping_processed_features.csv')
sub2_jumping_features = pd.read_csv('sub2_jumping_processed_features.csv')
sub3_jumping_features = pd.read_csv('sub3_jumping_processed_features.csv')
sub4_jumping_features = pd.read_csv('sub4_jumping_processed_features.csv')

sub1_running_features = pd.read_csv('sub1_Running_processed_features.csv')
sub2_running_features = pd.read_csv('sub2_Running_processed_features.csv')
sub3_running_features = pd.read_csv('sub3_Running_processed_features.csv')
sub4_running_features = pd.read_csv('sub4_Running_processed_features.csv')

sub1_seating_features = pd.read_csv('sub1_Seating_processed_features.csv')
sub2_seating_features = pd.read_csv('sub2_Seating_processed_features.csv')
sub3_seating_features = pd.read_csv('sub3_Seating_processed_features.csv')
sub4_seating_features = pd.read_csv('sub4_Seating_processed_features.csv')

sub1_standing_features = pd.read_csv('sub1_Standing_processed_features.csv')
sub2_standing_features = pd.read_csv('sub2_Standing_processed_features.csv')
sub3_standing_features = pd.read_csv('sub3_Standing_processed_features.csv')
sub4_standing_features = pd.read_csv('sub4_Standing_processed_features.csv')

sub1_walking_features = pd.read_csv('sub1_Walking_processed_features.csv')
sub2_walking_features = pd.read_csv('sub2_Walking_processed_features.csv')
sub3_walking_features = pd.read_csv('sub3_Walking_processed_features.csv')
sub4_walking_features = pd.read_csv('sub4_Walking_processed_features.csv')

sub1_waving_features = pd.read_csv('sub1_Waving_processed_features.csv')
sub2_waving_features = pd.read_csv('sub2_Waving_processed_features.csv')
sub3_waving_features = pd.read_csv('sub3_Waving_processed_features.csv')
sub4_waving_features = pd.read_csv('sub4_Waving_processed_features.csv')

# %%
sub1_frontkicking_features = pd.read_csv('sub1_frontkicking_processed_features.csv')
sub2_frontkicking_features = pd.read_csv('sub2_frontkicking_processed_features.csv')
sub3_frontkicking_features = pd.read_csv('sub3_frontkicking_processed_features.csv')
sub4_frontkicking_features = pd.read_csv('sub4_frontkicking_processed_features.csv')

sub1_elbowing_features = pd.read_csv('sub1_elbowing_processed_features.csv')
sub2_elbowing_features = pd.read_csv('sub2_elbowing_processed_features.csv')
sub3_elbowing_features = pd.read_csv('sub3_elbowing_processed_features.csv')
sub4_elbowing_features = pd.read_csv('sub4_elbowing_processed_features.csv')

sub1_hammering_features = pd.read_csv('sub1_Hammering_processed_features.csv')
sub2_hammering_features = pd.read_csv('sub2_Hammering_processed_features.csv')
sub3_hammering_features = pd.read_csv('sub3_Hammering_processed_features.csv')
sub4_hammering_features = pd.read_csv('sub4_Hammering_processed_features.csv')

sub1_headering_features = pd.read_csv('sub1_Headering_processed_features.csv')
sub2_headering_features = pd.read_csv('sub2_Headering_processed_features.csv')
sub3_headering_features = pd.read_csv('sub3_Headering_processed_features.csv')
sub4_headering_features = pd.read_csv('sub4_Headering_processed_features.csv')

sub1_kneeing_features = pd.read_csv('sub1_Kneeing_processed_features.csv')
sub2_kneeing_features = pd.read_csv('sub2_Kneeing_processed_features.csv')
sub3_kneeing_features = pd.read_csv('sub3_Kneeing_processed_features.csv')
sub4_kneeing_features = pd.read_csv('sub4_Kneeing_processed_features.csv')

sub1_pulling_features = pd.read_csv('sub1_pulling_processed_features.csv')
sub2_pulling_features = pd.read_csv('sub2_pulling_processed_features.csv')
sub3_pulling_features = pd.read_csv('sub3_pulling_processed_features.csv')
sub4_pulling_features = pd.read_csv('sub4_pulling_processed_features.csv')

sub1_punching_features = pd.read_csv('sub1_punching_processed_features.csv')
sub2_punching_features = pd.read_csv('sub2_punching_processed_features.csv')
sub3_punching_features = pd.read_csv('sub3_punching_processed_features.csv')
sub4_punching_features = pd.read_csv('sub4_punching_processed_features.csv')

sub1_pushing_features = pd.read_csv('sub1_pushing_processed_features.csv')
sub2_pushing_features = pd.read_csv('sub2_pushing_processed_features.csv')
sub3_pushing_features = pd.read_csv('sub3_pushing_processed_features.csv')
sub4_pushing_features = pd.read_csv('sub4_pushing_processed_features.csv')

sub1_sidekicking_features = pd.read_csv('sub1_sidekicking_processed_features.csv')
sub2_sidekicking_features = pd.read_csv('sub2_sidekicking_processed_features.csv')
sub3_sidekicking_features = pd.read_csv('sub3_sidekicking_processed_features.csv')
sub4_sidekicking_features = pd.read_csv('sub4_sidekicking_processed_features.csv')

sub1_slapping_features = pd.read_csv('sub1_slapping_processed_features.csv')
sub2_slapping_features = pd.read_csv('sub2_slapping_processed_features.csv')
sub3_slapping_features = pd.read_csv('sub3_slapping_processed_features.csv')
sub4_slapping_features = pd.read_csv('sub4_slapping_processed_features.csv')

# %% [markdown]
# ## Assigning Labels

# %%
# Assigning labels to Handshake as 0 and punching as 1

sub1_handshaking_features = sub1_handshaking_features.assign(label = [0]*len(sub1_handshaking_features))
sub2_handshaking_features = sub2_handshaking_features.assign(label = [0]*len(sub2_handshaking_features))
sub3_handshaking_features = sub3_handshaking_features.assign(label = [0]*len(sub3_handshaking_features))
sub4_handshaking_features = sub4_handshaking_features.assign(label = [0]*len(sub4_handshaking_features))

sub1_bowing_features = sub1_bowing_features.assign(label = [0]*len(sub1_bowing_features))
sub2_bowing_features = sub2_bowing_features.assign(label = [0]*len(sub2_bowing_features))
sub3_bowing_features = sub3_bowing_features.assign(label = [0]*len(sub3_bowing_features))
sub4_bowing_features = sub4_bowing_features.assign(label = [0]*len(sub4_bowing_features))

sub1_clapping_features = sub1_clapping_features.assign(label = [0]*len(sub1_clapping_features))
sub2_clapping_features = sub2_clapping_features.assign(label = [0]*len(sub2_clapping_features))
sub3_clapping_features = sub3_clapping_features.assign(label = [0]*len(sub3_clapping_features))
sub4_clapping_features = sub4_clapping_features.assign(label = [0]*len(sub4_clapping_features))

sub1_hugging_features = sub1_hugging_features.assign(label = [0]*len(sub1_hugging_features))
sub2_hugging_features = sub2_hugging_features.assign(label = [0]*len(sub2_hugging_features))
sub3_hugging_features = sub3_hugging_features.assign(label = [0]*len(sub3_hugging_features))
sub4_hugging_features = sub4_hugging_features.assign(label = [0]*len(sub4_hugging_features))

sub1_jumping_features = sub1_jumping_features.assign(label = [0]*len(sub1_jumping_features))
sub2_jumping_features = sub2_jumping_features.assign(label = [0]*len(sub2_jumping_features))
sub3_jumping_features = sub3_jumping_features.assign(label = [0]*len(sub3_jumping_features))
sub4_jumping_features = sub4_jumping_features.assign(label = [0]*len(sub4_jumping_features))

sub1_running_features = sub1_running_features.assign(label = [0]*len(sub1_running_features))
sub2_running_features = sub2_running_features.assign(label = [0]*len(sub2_running_features))
sub3_running_features = sub3_running_features.assign(label = [0]*len(sub3_running_features))
sub4_running_features = sub4_running_features.assign(label = [0]*len(sub4_running_features))

sub1_seating_features = sub1_seating_features.assign(label = [0]*len(sub1_seating_features))
sub2_seating_features = sub2_seating_features.assign(label = [0]*len(sub2_seating_features))
sub3_seating_features = sub3_seating_features.assign(label = [0]*len(sub3_seating_features))
sub4_seating_features = sub4_seating_features.assign(label = [0]*len(sub4_seating_features))

sub1_standing_features = sub1_standing_features.assign(label = [0]*len(sub1_standing_features))
sub2_standing_features = sub2_standing_features.assign(label = [0]*len(sub2_standing_features))
sub3_standing_features = sub3_standing_features.assign(label = [0]*len(sub3_standing_features))
sub4_standing_features = sub4_standing_features.assign(label = [0]*len(sub4_standing_features))

sub1_walking_features = sub1_walking_features.assign(label = [0]*len(sub1_walking_features))
sub2_walking_features = sub2_walking_features.assign(label = [0]*len(sub2_walking_features))
sub3_walking_features = sub3_walking_features.assign(label = [0]*len(sub3_walking_features))
sub4_walking_features = sub4_walking_features.assign(label = [0]*len(sub4_walking_features))

sub1_waving_features = sub1_waving_features.assign(label = [0]*len(sub1_waving_features))
sub2_waving_features = sub2_waving_features.assign(label = [0]*len(sub2_waving_features))
sub3_waving_features = sub3_waving_features.assign(label = [0]*len(sub3_waving_features))
sub4_waving_features = sub4_waving_features.assign(label = [0]*len(sub4_waving_features))

# %%
sub1_punching_features = sub1_punching_features.assign(label = [1]*len(sub1_punching_features))
sub2_punching_features = sub2_punching_features.assign(label = [1]*len(sub2_punching_features))
sub3_punching_features = sub3_punching_features.assign(label = [1]*len(sub3_punching_features))
sub4_punching_features = sub4_punching_features.assign(label = [1]*len(sub4_punching_features))

sub1_frontkicking_features = sub1_frontkicking_features.assign(label = [1]*len(sub1_frontkicking_features))
sub2_frontkicking_features = sub2_frontkicking_features.assign(label = [1]*len(sub2_frontkicking_features))
sub3_frontkicking_features = sub3_frontkicking_features.assign(label = [1]*len(sub3_frontkicking_features))
sub4_frontkicking_features = sub4_frontkicking_features.assign(label = [1]*len(sub4_frontkicking_features))

sub1_elbowing_features = sub1_elbowing_features.assign(label = [1]*len(sub1_elbowing_features))
sub2_elbowing_features = sub2_elbowing_features.assign(label = [1]*len(sub2_elbowing_features))
sub3_elbowing_features = sub3_elbowing_features.assign(label = [1]*len(sub3_elbowing_features))
sub4_elbowing_features = sub4_elbowing_features.assign(label = [1]*len(sub4_elbowing_features))

sub1_hammering_features = sub1_hammering_features.assign(label = [1]*len(sub1_hammering_features))
sub2_hammering_features = sub2_hammering_features.assign(label = [1]*len(sub2_hammering_features))
sub3_hammering_features = sub3_hammering_features.assign(label = [1]*len(sub3_hammering_features))
sub4_hammering_features = sub4_hammering_features.assign(label = [1]*len(sub4_hammering_features))

sub1_headering_features = sub1_headering_features.assign(label = [1]*len(sub1_headering_features))
sub2_headering_features = sub2_headering_features.assign(label = [1]*len(sub2_headering_features))
sub3_headering_features = sub3_headering_features.assign(label = [1]*len(sub3_headering_features))
sub4_headering_features = sub4_headering_features.assign(label = [1]*len(sub4_headering_features))

sub1_kneeing_features = sub1_kneeing_features.assign(label = [1]*len(sub1_kneeing_features))
sub2_kneeing_features = sub2_kneeing_features.assign(label = [1]*len(sub2_kneeing_features))
sub3_kneeing_features = sub3_kneeing_features.assign(label = [1]*len(sub3_kneeing_features))
sub4_kneeing_features = sub4_kneeing_features.assign(label = [1]*len(sub4_kneeing_features))

sub1_pulling_features = sub1_pulling_features.assign(label = [1]*len(sub1_pulling_features))
sub2_pulling_features = sub2_pulling_features.assign(label = [1]*len(sub2_pulling_features))
sub3_pulling_features = sub3_pulling_features.assign(label = [1]*len(sub3_pulling_features))
sub4_pulling_features = sub4_pulling_features.assign(label = [1]*len(sub4_pulling_features))

sub1_punching_features = sub1_punching_features.assign(label = [1]*len(sub1_punching_features))
sub2_punching_features = sub2_punching_features.assign(label = [1]*len(sub2_punching_features))
sub3_punching_features = sub3_punching_features.assign(label = [1]*len(sub3_punching_features))
sub4_punching_features = sub4_punching_features.assign(label = [1]*len(sub4_punching_features))

sub1_pushing_features = sub1_pushing_features.assign(label = [1]*len(sub1_pushing_features))
sub2_pushing_features = sub2_pushing_features.assign(label = [1]*len(sub2_pushing_features))
sub3_pushing_features = sub3_pushing_features.assign(label = [1]*len(sub3_pushing_features))
sub4_pushing_features = sub4_pushing_features.assign(label = [1]*len(sub4_pushing_features))

sub1_sidekicking_features = sub1_sidekicking_features.assign(label = [1]*len(sub1_sidekicking_features))
sub2_sidekicking_features = sub2_sidekicking_features.assign(label = [1]*len(sub2_sidekicking_features))
sub3_sidekicking_features = sub3_sidekicking_features.assign(label = [1]*len(sub3_sidekicking_features))
sub4_sidekicking_features = sub4_sidekicking_features.assign(label = [1]*len(sub4_sidekicking_features))

sub1_slapping_features = sub1_slapping_features.assign(label = [1]*len(sub1_slapping_features))
sub2_slapping_features = sub2_slapping_features.assign(label = [1]*len(sub2_slapping_features))
sub3_slapping_features = sub3_slapping_features.assign(label = [1]*len(sub3_slapping_features))
sub4_slapping_features = sub4_slapping_features.assign(label = [1]*len(sub4_slapping_features))

# %%
sub4_slapping_features.shape
# Out:
# (91, 6306)

# %% [markdown]
# ## Standardizing subjectwise

# %% [markdown]
# ## Functions:

# %%
def get_pred_default(train,test):
    
    n,m = train.shape 
    X = train.iloc[:,:m-1]# get training input data
    query = test.iloc[:,:m-1]# get test input data
    
    #Get the frequently occuring category in training data
    arity_name, arity_freq = np.unique(train.iloc[:,m-1], return_counts = True)
    for i in range(0,len(arity_freq)):
        if(arity_freq[i] == max(arity_freq)):
            pred_def = i
            prob = float(arity_freq[i])/float(len(train))
    predicted_response = [pred_def]*len(test)
    predicted_prob = [prob]*len(test)
    return pd.DataFrame({'Predicted':predicted_response, 'Actual':test.iloc[:,m-1], 'Probability':predicted_prob})

def get_pred_nb(train,test):
    n,m = train.shape # number of rows and columns
    X = train.iloc[:,:m-1]# get training input data
    query = test.iloc[:,:m-1]# get test input data    
    gnb = GaussianNB()
    gnb.fit(X,train.iloc[:,m-1])
    predicted_response = gnb.predict(query)
    predicted_prob = gnb.predict_proba(query)[:, 1]
    return pd.DataFrame({'Predicted':predicted_response, 'Actual':test.iloc[:,m-1], 'Probability':predicted_prob})

def get_pred_logreg(train,test):
    n,m = train.shape # number of rows and columns
    X = train.iloc[:,:m-1]# get training input data
    y = train.iloc[:,m-1]
    query = test.iloc[:,:m-1]# get test input data    
    lm = LogisticRegression()
    lm.fit(X,y)
    predicted_response = lm.predict(query)
    predicted_prob = lm.predict_proba(query)[:, 1]
    return pd.DataFrame({'Predicted':predicted_response, 'Actual':test.iloc[:,m-1], 'Probability':predicted_prob})

def get_pred_rf(train,test):
    n,m = train.shape # number of rows and columns
    X = train.iloc[:,:m-1]# get training input data
    y = train.iloc[:,m-1]
    query = test.iloc[:,:m-1]    
    rf = RandomForestClassifier(n_estimators=100)
    rf.fit(X,y)
    predicted_response = rf.predict(query)
    predicted_prob = rf.predict_proba(query)[:, 1]
    return pd.DataFrame({'Predicted':predicted_response, 'Actual':test.iloc[:,m-1], 'Probability':predicted_prob})

# %%
def get_metrics(pred, cutoff=0.5):
    
    predicted_output = [float(i) for i in pred.loc[:,'Predicted']] # first column of list are the Predicted values
    actual_output = [float(i) for i in pred.loc[:,'Actual']] # Second column of list are the Actual values
    # returns list = [[FALSE, TRUE][IF CONDITION] FOR a row in LIST]
    predicted_output_manipulate = [[0, 1][x > cutoff] for x in predicted_output] # can also be performed by map(lambda x: [0, 1][x > cutoff], predicted_output)

    n11_TP = sum([[0, 1][predicted_output_manipulate[i] == 1 and actual_output[i] == 1] for i in range(len(predicted_output))])
    n00_TN = sum([[0, 1][predicted_output_manipulate[i] == 0 and actual_output[i] == 0] for i in range(len(predicted_output))])
    n10_FN = sum([[0, 1][predicted_output_manipulate[i] == 0 and actual_output[i] == 1] for i in range(len(predicted_output))])
    n01_FP = sum([[0, 1][predicted_output_manipulate[i] == 1 and actual_output[i] == 0] for i in range(len(predicted_output))])
    Pos = n11_TP + n10_FN
    Neg = n01_FP + n00_TN
    PPos = n11_TP + n01_FP
    PNeg = n10_FN + n00_TN
    
    if(Neg == 0):
        Accuracy = float(n11_TP+n00_TN)/float(Pos+Neg)
        Recall = float(n11_TP)/float(Pos)
        Precision = float(n11_TP)/float(PPos)
        TP_rate = float(n11_TP)/float(Pos)
        FP_rate = 'N/A'
    elif(Pos == 0):
        TP_rate = 'N/A'
        FP_rate = float(n01_FP)/float(Neg)
        Accuracy = float(n11_TP+n00_TN)/float(Pos+Neg)
        Precision = float(n11_TP)/float(PPos)
        Recall = 'N/A'
    elif(PPos == 0):
        TP_rate = float(n11_TP)/float(Pos)
        FP_rate = float(n01_FP)/float(Neg)
        Accuracy = float(n11_TP+n00_TN)/float(Pos+Neg)
        Precision = 'N/A'
        Recall = float(n11_TP)/float(Pos)
    else:
        TP_rate = float(n11_TP)/float(Pos)
        FP_rate = float(n01_FP)/float(Neg)
        Accuracy = float(n11_TP+n00_TN)/float(Pos+Neg)
        Precision = float(n11_TP)/float(PPos)
        Recall = float(n11_TP)/float(Pos)
   
    print(pd.DataFrame({'True Positive Rate':TP_rate, 'False Positive Rate':FP_rate, 'Accuracy':Accuracy, 'Precision':Precision, 'Recall':Recall}, index = [0]))
    
    return Accuracy, Precision, Recall

# %%
def print_cont_table(pred, cutoff=0.5):

    predicted_output = [float(i) for i in pred.loc[:,'Predicted']] # first column of list are the Predicted values
    actual_output = [float(i) for i in pred.loc[:,'Actual']] # Second column of list are the Actual values
    predicted_output_manipulate = [[0, 1][x > cutoff] for x in predicted_output] # can also be performed by map(lambda x: [0, 1][x > cutoff], predicted_output)

    n11_TP = sum([[0, 1][predicted_output_manipulate[i] == 1 and actual_output[i] == 1] for i in range(len(predicted_output))])
    n00_TN = sum([[0, 1][predicted_output_manipulate[i] == 0 and actual_output[i] == 0] for i in range(len(predicted_output))])
    n10_FN = sum([[0, 1][predicted_output_manipulate[i] == 0 and actual_output[i] == 1] for i in range(len(predicted_output))])
    n01_FP = sum([[0, 1][predicted_output_manipulate[i] == 1 and actual_output[i] == 0] for i in range(len(predicted_output))])
    Pos = n11_TP + n10_FN
    Neg = n01_FP + n00_TN
    PPos = n11_TP + n01_FP
    PNeg = n10_FN + n00_TN
    print ("           |  PPos \t PNeg \t | Sums")
    print ("-------------------------------------")
    print ("actual pos |  %d \t %d \t | %d" % (n11_TP, n10_FN, Pos))
    print ("actual neg |  %d \t %d \t | %d" % (n01_FP, n00_TN, Neg))
    print ("-------------------------------------")
    print ("Sums       |  %d \t %d \t | %d" % (PPos, PNeg, (Pos+Neg)))
    return None

# %% [markdown]
# ## Leave one subject out Cross-Validation

# %%
subject1 = pd.concat([sub1_handshaking_features,sub1_punching_features,sub1_seating_features,sub1_standing_features,sub1_pushing_features,sub1_pulling_features,sub1_slapping_features,sub1_sidekicking_features,sub1_frontkicking_features,sub1_kneeing_features,sub1_hammering_features, sub1_hugging_features,sub1_headering_features,sub1_jumping_features,sub1_bowing_features,sub1_elbowing_features,sub1_running_features,sub1_walking_features,sub1_clapping_features,sub1_waving_features])
subject2 = pd.concat([sub2_handshaking_features,sub2_punching_features,sub2_seating_features,sub2_standing_features,sub2_pushing_features,sub2_pulling_features,sub2_slapping_features,sub2_sidekicking_features,sub2_frontkicking_features,sub2_kneeing_features,sub2_hammering_features, sub2_hugging_features,sub2_headering_features,sub2_jumping_features,sub2_bowing_features,sub2_elbowing_features,sub2_running_features,sub2_walking_features,sub2_clapping_features,sub2_waving_features])
subject3 = pd.concat([sub3_handshaking_features,sub3_punching_features,sub3_seating_features,sub3_standing_features,sub3_pushing_features,sub3_pulling_features,sub3_slapping_features,sub3_sidekicking_features,sub3_frontkicking_features,sub3_kneeing_features,sub3_hammering_features, sub3_hugging_features,sub3_headering_features,sub3_jumping_features,sub3_bowing_features,sub3_elbowing_features,sub3_running_features,sub3_walking_features,sub3_clapping_features,sub3_waving_features])
subject4 = pd.concat([sub4_handshaking_features,sub4_punching_features,sub4_seating_features,sub4_standing_features,sub4_pushing_features,sub4_pulling_features,sub4_slapping_features,sub4_sidekicking_features,sub4_frontkicking_features,sub4_kneeing_features,sub4_hammering_features, sub4_hugging_features,sub4_headering_features,sub4_jumping_features,sub4_bowing_features,sub4_elbowing_features,sub4_running_features,sub4_walking_features,sub4_clapping_features,sub4_waving_features])

# %% [markdown]
# ### Check for nans and infs

# %%
#DROP ID column

subject1 = subject1.drop(['id'],axis=1)
subject2 = subject2.drop(['id'],axis=1)
subject3 = subject3.drop(['id'],axis=1)
subject4 = subject4.drop(['id'],axis=1)

#fillNA

subject1 = subject1.fillna(subject1.mean())
subject2 = subject2.fillna(subject2.mean())
subject3 = subject3.fillna(subject3.mean())
subject4 = subject4.fillna(subject4.mean())

# %%
#Standardizing
X = subject1.copy()
labeled = list(X.loc[:,'label'])
X = X.drop(['label'],axis = 1)
scaler = preprocessing.StandardScaler().fit(X)
X_scaled = scaler.transform(X)                           
X_scaled = pd.DataFrame(X_scaled)
X_scaled.columns = X.columns
subject1 = X_scaled
subject1 = subject1.assign(label = labeled)

query = subject2.copy()
labeled = list(query.loc[:,'label'])
query = query.drop(['label'],axis = 1)
query_scaled = scaler.transform(query)
query_scaled = pd.DataFrame(query_scaled)
query_scaled.columns = query.columns
subject2 = query_scaled
subject2 = subject2.assign(label = labeled)


query = subject3.copy()
labeled = list(query.loc[:,'label'])
query = query.drop(['label'],axis = 1)
query_scaled = scaler.transform(query)
query_scaled = pd.DataFrame(query_scaled)
query_scaled.columns = query.columns
subject3 = query_scaled
subject3 = subject3.assign(label = labeled)


query = subject4.copy()
labeled = list(query.loc[:,'label'])
query = query.drop(['label'],axis = 1)
query_scaled = scaler.transform(query)
query_scaled = pd.DataFrame(query_scaled)
query_scaled.columns = query.columns
subject4 = query_scaled
subject4 = subject4.assign(label = labeled)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-9e6e3f2209e4> in <module>()
#       1 #Standardizing
# ----> 2 X = subject1.copy()
#       3 labeled = list(X.loc[:,'label'])
#       4 X = X.drop(['label'],axis = 1)
#       5 scaler = preprocessing.StandardScaler().fit(X)
#
# NameError: name 'subject1' is not defined

# %%
def crossvalidate(subject1, subject2, subject3, subject4):
    trainlist = [subject1, subject2, subject3, subject4]
    Accuracy1_array = []
    Accuracy2_array = []
    Accuracy3_array = []
    Accuracy0_array = []
    default_test = []
    default_prob = []
    log_test = []
    log_prob = []
    nb_test = []
    nb_prob = []
    rf_test = []
    rf_prob = []
    
    for i in range(0,len(trainlist)):
        templist = copy.deepcopy(trainlist)
        test = templist[i]
        templist.pop(i)
        train = pd.concat(templist)
        print('\nLeave subject '+str(i+1)+' out\n')
        print('Default model\n')
        check = get_pred_default(train,test)
        print_cont_table(check)
        Accuracy0, Precision0, Recall0  = get_metrics(check)
        y_test = check.loc[:,'Actual']
        default_test = np.append(default_test,y_test)
        y_prob = check.loc[:,'Probability']
        default_prob = np.append(default_prob,y_prob)
        fpr_d, tpr_d, _ = roc_curve(y_test, y_prob)
        roc_auc_d = metrics.auc(fpr_d, tpr_d)
        print('\n')
        print('Naives Bayes\n')
        check = get_pred_nb(train,test)
        print_cont_table(check)
        Accuracy1, Precision1, Recall1  = get_metrics(check)
        y_test = check.loc[:,'Actual']
        nb_test = np.append(nb_test,y_test)
        y_prob = check.loc[:,'Probability']
        nb_prob = np.append(nb_prob,y_prob)
        fpr_nb, tpr_nb, _ = roc_curve(y_test, y_prob)
        roc_auc_nb = metrics.auc(fpr_nb, tpr_nb)
        print('\n')
        print('Logistic regression\n')
        check = get_pred_logreg(train,test)
        print_cont_table(check)
        Accuracy2, Precision2, Recall2  = get_metrics(check)
        y_test = check.loc[:,'Actual']
        log_test = np.append(log_test, y_test)
        y_prob = check.loc[:,'Probability']
        log_prob = np.append(log_prob, y_prob)
        fpr_lr, tpr_lr, _ = roc_curve(y_test, y_prob)
        roc_auc_lr = metrics.auc(fpr_lr, tpr_lr)
        print('\n')
        print('Random Forest\n')
        check = get_pred_rf(train,test)
        print_cont_table(check)
        Accuracy3, Precision3, Recall3  = get_metrics(check)
        y_test = check.loc[:,'Actual']
        rf_test = np.append(rf_test,y_test)
        y_prob = check.loc[:,'Probability']
        rf_prob = np.append(rf_prob, y_prob)
        fpr_rf, tpr_rf, _ = roc_curve(y_test, y_prob)
        roc_auc_rf = metrics.auc(fpr_rf, tpr_rf)
        print('\n')
        plt.plot([0, 1], [0, 1], 'k--')
        plt.plot(fpr_d, tpr_d, label='Default (AUC ='+str(roc_auc_d)+')')
        plt.plot(fpr_nb, tpr_nb, label='Naives Bayes (AUC ='+str(roc_auc_nb)+')')
        plt.plot(fpr_lr, tpr_lr, label='LogReg (AUC ='+str(roc_auc_lr)+')')
        plt.plot(fpr_rf, tpr_rf, label='RF (AUC ='+str(roc_auc_rf)+')')
        plt.xlim([-0.05, 1.05])
        plt.ylim([-0.05, 1.05])
        plt.xlabel('False positive rate')
        plt.ylabel('True positive rate')
        plt.title('Leave subject '+str(i+1)+' out (Fold '+str(i+1)+')')
        plt.legend(loc='best')
        plt.show()
        
        Accuracy1_array = np.append(Accuracy1_array, Accuracy1);
        Accuracy2_array = np.append(Accuracy2_array, Accuracy2);
        Accuracy3_array = np.append(Accuracy3_array, Accuracy3);
        Accuracy0_array = np.append(Accuracy0_array, Accuracy0);
    print('\n')
    
    fpr_d, tpr_d, _ = roc_curve(default_test, default_prob)
    roc_auc_d = metrics.auc(fpr_d, tpr_d)
    fpr_nb, tpr_nb, _ = roc_curve(nb_test, nb_prob)
    roc_auc_nb = metrics.auc(fpr_nb, tpr_nb)
    fpr_lr, tpr_lr, _ = roc_curve(log_test, log_prob)
    roc_auc_lr = metrics.auc(fpr_lr, tpr_lr)
    fpr_rf, tpr_rf, _ = roc_curve(rf_test, rf_prob)
    roc_auc_rf = metrics.auc(fpr_rf, tpr_rf)
    
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr_d, tpr_d, label='Default (AUC ='+str(roc_auc_d)+')')
    plt.plot(fpr_nb, tpr_nb, label='Naives Bayes (AUC ='+str(roc_auc_nb)+')')
    plt.plot(fpr_lr, tpr_lr, label='LogReg (AUC ='+str(roc_auc_lr)+')')
    plt.plot(fpr_rf, tpr_rf, label='RF (AUC ='+str(roc_auc_rf)+')')
    plt.xlim([-0.05, 1.05])
    plt.ylim([-0.05, 1.05])
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC over all folds')
    plt.legend(loc='best')
    plt.show()

    
    
    return Accuracy0_array,Accuracy1_array, Accuracy2_array, Accuracy3_array

# %%
Accuracy0_array,Accuracy1_array, Accuracy2_array, Accuracy3_array = crossvalidate(subject1,subject2,subject3,subject4)
# Out:
# Leave subject 1 out
#
# Default model
#
#            |  PPos 	 PNeg 	 | Sums
# -------------------------------------
# actual pos |  888 	 0 	 | 888
# actual neg |  897 	 0 	 | 897
# -------------------------------------
# Sums       |  1785 	 0 	 | 1785
#    Accuracy  False Positive Rate  Precision  Recall  True Positive Rate
# 0  0.497479                  1.0   0.497479     1.0                 1.0
#
#
# Naives Bayes
#
#            |  PPos 	 PNeg 	 | Sums
# -------------------------------------
# actual pos |  763 	 125 	 | 888
# actual neg |  11 	 886 	 | 897
# -------------------------------------
# Sums       |  774 	 1011 	 | 1785
#    Accuracy  False Positive Rate  Precision    Recall  True Positive Rate
# 0   0.92381             0.012263   0.985788  0.859234            0.859234
#
#
# Logistic regression
#
#            |  PPos 	 PNeg 	 | Sums
# -------------------------------------
# actual pos |  769 	 119 	 | 888
# actual neg |  1 	 896 	 | 897
# ...

# %%
print(np.mean(Accuracy0_array))
print(np.mean(Accuracy1_array))
print(np.mean(Accuracy2_array))
print(np.mean(Accuracy3_array))
# Out:
# 0.49508564752749923
# 0.8662224699104223
# 0.849086833587192
# 0.8467945298801733

# %%
N = 4
ind = np.arange(N)  # the x locations for the groups
width = 0.10       # the width of the bars

fig = plt.figure(figsize=(11,6))
plt.title('Normal vs. Aggressive Actions CV results')
ax = fig.add_subplot(111)

yvals = [Accuracy0_array[0], Accuracy0_array[1],Accuracy0_array[2], Accuracy0_array[3]]
rects1 = ax.bar(ind, yvals, width, color='skyblue')
zvals = [Accuracy1_array[0], Accuracy1_array[1],Accuracy1_array[2], Accuracy1_array[3]]
rects2 = ax.bar(ind+width, zvals, width, color='indianred')
kvals = [Accuracy2_array[0], Accuracy2_array[1],Accuracy2_array[2], Accuracy2_array[3]]
rects3 = ax.bar(ind+width*2, kvals, width, color='yellow')
xvals = [Accuracy3_array[0], Accuracy3_array[1],Accuracy3_array[2], Accuracy3_array[3]]
rects4 = ax.bar(ind+width*3, xvals, width, color='pink')

ax.set_ylabel('Accuracy at 0.5 threshold')
ax.set_xticks(ind+width)
ax.set_ylim([0,1.15])
ax.set_xticklabels( ('Leave Sub1/Fold 1', 'Leave Sub2/Fold 2', 'Leave Sub3/Fold 3', 'Leave Sub4/Fold 4') )
ax.legend( (rects1[0], rects2[0], rects3[0],rects4[0]), ('Default', 'Naive Bayes','Logistic Regression', 'Random Forests'), loc = 'upper right' )
# Out:
# C:\Users\Bhavya\Anaconda3\envs\AppliedDataScience\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ## Random Forest feature importance

# %%
entire_data = pd.concat([subject1, subject2, subject3, subject4])
n,m = entire_data.shape # number of rows and columns
X = entire_data.iloc[:,:m-1]# get training input data
y = entire_data.iloc[:,m-1]

#Standardizing
scaler = preprocessing.StandardScaler().fit(X)
X_scaled = scaler.transform(X)                           
X_scaled = pd.DataFrame(X_scaled)
X_scaled.columns = X.columns
X = X_scaled

# %%
rf = RandomForestClassifier(n_estimators = 100)
rf.fit(X,y)
feature_importances = pd.DataFrame(rf.feature_importances_,
                                   index = X.columns,
                                    columns=['importance']).sort_values('importance', ascending=False)
display(feature_importances)

# %%
for i in range(0,6416):
    display (feature_importances.iloc[i])

# %% [markdown]
# _________________________________________________________________________________________________________________________

# %% [markdown]
# ## Feature Space Engineering

# %%
def feature_space(data,features_remove):
    n,m = sub1_bowing_features.shape
    toremove = set()
    for i in range(1,m):
        column_name = data.columns[i]
        for f in features_remove:
            if f in column_name:
                toremove.add(column_name)
    return data.drop(labels = list(toremove),axis=1)

# %%
features_remove_1 = ["lag","ar_coefficient","mean_second_derivative_central","time_reversal_asymmetry_statistic"]

# %%
sub1_handshaking_features_1 = feature_space(sub1_handshaking_features,features_remove_1)
sub2_handshaking_features_1 = feature_space(sub2_handshaking_features,features_remove_1)
sub3_handshaking_features_1 = feature_space(sub3_handshaking_features,features_remove_1)
sub4_handshaking_features_1 = feature_space(sub3_handshaking_features,features_remove_1)

sub1_bowing_features_1 = feature_space(sub1_bowing_features,features_remove_1)
sub2_bowing_features_1 = feature_space(sub2_bowing_features,features_remove_1)
sub3_bowing_features_1 = feature_space(sub3_bowing_features,features_remove_1)
sub4_bowing_features_1 = feature_space(sub3_bowing_features,features_remove_1)

sub1_clapping_features_1 = feature_space(sub1_clapping_features,features_remove_1)
sub2_clapping_features_1 = feature_space(sub2_clapping_features,features_remove_1)
sub3_clapping_features_1 = feature_space(sub3_clapping_features,features_remove_1)
sub4_clapping_features_1 = feature_space(sub3_clapping_features,features_remove_1)

sub1_punching_features_1 = feature_space(sub1_punching_features,features_remove_1)
sub2_punching_features_1 = feature_space(sub2_punching_features,features_remove_1)
sub3_punching_features_1 = feature_space(sub3_punching_features,features_remove_1)
sub4_punching_features_1 = feature_space(sub3_punching_features,features_remove_1)

sub1_frontkicking_features_1 = feature_space(sub1_frontkicking_features,features_remove_1)
sub2_frontkicking_features_1 = feature_space(sub2_frontkicking_features,features_remove_1)
sub3_frontkicking_features_1 = feature_space(sub3_frontkicking_features,features_remove_1)
sub4_frontkicking_features_1 = feature_space(sub3_frontkicking_features,features_remove_1)

sub1_elbowing_features_1 = feature_space(sub1_elbowing_features,features_remove_1)
sub2_elbowing_features_1 = feature_space(sub2_elbowing_features,features_remove_1)
sub3_elbowing_features_1 = feature_space(sub3_elbowing_features,features_remove_1)
sub4_elbowing_features_1 = feature_space(sub3_elbowing_features,features_remove_1)

sub1_hammering_features_1 = feature_space(sub1_hammering_features,features_remove_1)
sub2_hammering_features_1 = feature_space(sub2_hammering_features,features_remove_1)
sub3_hammering_features_1 = feature_space(sub3_hammering_features,features_remove_1)
sub4_hammering_features_1 = feature_space(sub3_hammering_features,features_remove_1)

sub1_headering_features_1 = feature_space(sub1_headering_features,features_remove_1)
sub2_headering_features_1 = feature_space(sub2_headering_features,features_remove_1)
sub3_headering_features_1 = feature_space(sub3_headering_features,features_remove_1)
sub4_headering_features_1 = feature_space(sub3_headering_features,features_remove_1)

sub1_kneeing_features_1 = feature_space(sub1_kneeing_features,features_remove_1)
sub2_kneeing_features_1 = feature_space(sub2_kneeing_features,features_remove_1)
sub3_kneeing_features_1 = feature_space(sub3_kneeing_features,features_remove_1)
sub4_kneeing_features_1 = feature_space(sub3_kneeing_features,features_remove_1)

sub1_pulling_features_1 = feature_space(sub1_pulling_features,features_remove_1)
sub2_pulling_features_1 = feature_space(sub2_pulling_features,features_remove_1)
sub3_pulling_features_1 = feature_space(sub3_pulling_features,features_remove_1)
sub4_pulling_features_1 = feature_space(sub3_pulling_features,features_remove_1)

sub1_punching_features_1 = feature_space(sub1_punching_features,features_remove_1)
sub2_punching_features_1 = feature_space(sub2_punching_features,features_remove_1)
sub3_punching_features_1 = feature_space(sub3_punching_features,features_remove_1)
sub4_punching_features_1 = feature_space(sub3_punching_features,features_remove_1)

sub1_pushing_features_1 = feature_space(sub1_pushing_features,features_remove_1)
sub2_pushing_features_1 = feature_space(sub2_pushing_features,features_remove_1)
sub3_pushing_features_1 = feature_space(sub3_pushing_features,features_remove_1)
sub4_pushing_features_1 = feature_space(sub3_pushing_features,features_remove_1)

sub1_sidekicking_features_1 = feature_space(sub1_sidekicking_features,features_remove_1)
sub2_sidekicking_features_1 = feature_space(sub2_sidekicking_features,features_remove_1)
sub3_sidekicking_features_1 = feature_space(sub3_sidekicking_features,features_remove_1)
sub4_sidekicking_features_1 = feature_space(sub3_sidekicking_features,features_remove_1)

sub1_slapping_features_1 = feature_space(sub1_slapping_features,features_remove_1)
sub2_slapping_features_1 = feature_space(sub2_slapping_features,features_remove_1)
sub3_slapping_features_1 = feature_space(sub3_slapping_features,features_remove_1)
sub4_slapping_features_1 = feature_space(sub3_slapping_features,features_remove_1)

sub1_hugging_features_1 = feature_space(sub1_hugging_features,features_remove_1)
sub2_hugging_features_1 = feature_space(sub2_hugging_features,features_remove_1)
sub3_hugging_features_1 = feature_space(sub3_hugging_features,features_remove_1)
sub4_hugging_features_1 = feature_space(sub3_hugging_features,features_remove_1)

sub1_jumping_features_1 = feature_space(sub1_jumping_features,features_remove_1)
sub2_jumping_features_1 = feature_space(sub2_jumping_features,features_remove_1)
sub3_jumping_features_1 = feature_space(sub3_jumping_features,features_remove_1)
sub4_jumping_features_1 = feature_space(sub3_jumping_features,features_remove_1)

sub1_running_features_1 = feature_space(sub1_running_features,features_remove_1)
sub2_running_features_1 = feature_space(sub2_running_features,features_remove_1)
sub3_running_features_1 = feature_space(sub3_running_features,features_remove_1)
sub4_running_features_1 = feature_space(sub3_running_features,features_remove_1)

sub1_seating_features_1 = feature_space(sub1_seating_features,features_remove_1)
sub2_seating_features_1 = feature_space(sub2_seating_features,features_remove_1)
sub3_seating_features_1 = feature_space(sub3_seating_features,features_remove_1)
sub4_seating_features_1 = feature_space(sub3_seating_features,features_remove_1)

sub1_standing_features_1 = feature_space(sub1_standing_features,features_remove_1)
sub2_standing_features_1 = feature_space(sub2_standing_features,features_remove_1)
sub3_standing_features_1 = feature_space(sub3_standing_features,features_remove_1)
sub4_standing_features_1 = feature_space(sub3_standing_features,features_remove_1)

sub1_walking_features_1 = feature_space(sub1_walking_features,features_remove_1)
sub2_walking_features_1 = feature_space(sub2_walking_features,features_remove_1)
sub3_walking_features_1 = feature_space(sub3_walking_features,features_remove_1)
sub4_walking_features_1 = feature_space(sub3_walking_features,features_remove_1)

sub1_waving_features_1 = feature_space(sub1_waving_features,features_remove_1)
sub2_waving_features_1 = feature_space(sub2_waving_features,features_remove_1)
sub3_waving_features_1 = feature_space(sub3_waving_features,features_remove_1)
sub4_waving_features_1 = feature_space(sub3_waving_features,features_remove_1)

# %% [markdown]
# ## Leave one subject out Cross-Validation

# %%
subject1 = pd.concat([sub1_handshaking_features_1,sub1_punching_features_1,sub1_seating_features_1,sub1_standing_features_1,sub1_pushing_features_1,sub1_pulling_features_1,sub1_slapping_features_1,sub1_sidekicking_features_1,sub1_frontkicking_features_1,sub1_kneeing_features_1,sub1_hammering_features_1, sub1_hugging_features_1,sub1_headering_features_1,sub1_jumping_features_1,sub1_bowing_features_1,sub1_elbowing_features_1,sub1_running_features_1,sub1_walking_features_1,sub1_clapping_features_1,sub1_waving_features_1])
subject2 = pd.concat([sub2_handshaking_features_1,sub2_punching_features_1,sub2_seating_features_1,sub2_standing_features_1,sub2_pushing_features_1,sub2_pulling_features_1,sub2_slapping_features_1,sub2_sidekicking_features_1,sub2_frontkicking_features_1,sub2_kneeing_features_1,sub2_hammering_features_1, sub2_hugging_features_1,sub2_headering_features_1,sub2_jumping_features_1,sub2_bowing_features_1,sub2_elbowing_features_1,sub2_running_features_1,sub2_walking_features_1,sub2_clapping_features_1,sub2_waving_features_1])
subject3 = pd.concat([sub3_handshaking_features_1,sub3_punching_features_1,sub3_seating_features_1,sub3_standing_features_1,sub3_pushing_features_1,sub3_pulling_features_1,sub3_slapping_features_1,sub3_sidekicking_features_1,sub3_frontkicking_features_1,sub3_kneeing_features_1,sub3_hammering_features_1, sub3_hugging_features_1,sub3_headering_features_1,sub3_jumping_features_1,sub3_bowing_features_1,sub3_elbowing_features_1,sub3_running_features_1,sub3_walking_features_1,sub3_clapping_features_1,sub3_waving_features_1])
subject4 = pd.concat([sub4_handshaking_features_1,sub4_punching_features_1,sub4_seating_features_1,sub4_standing_features_1,sub4_pushing_features_1,sub4_pulling_features_1,sub4_slapping_features_1,sub4_sidekicking_features_1,sub4_frontkicking_features_1,sub4_kneeing_features_1,sub4_hammering_features_1, sub4_hugging_features_1,sub4_headering_features_1,sub4_jumping_features_1,sub4_bowing_features_1,sub4_elbowing_features_1,sub4_running_features_1,sub4_walking_features_1,sub4_clapping_features_1,sub4_waving_features_1])

# %% [markdown]
# ### Check for nans and infs

# %%
#DROP ID column

subject1 = subject1.drop(['id'],axis=1)
subject2 = subject2.drop(['id'],axis=1)
subject3 = subject3.drop(['id'],axis=1)
subject4 = subject4.drop(['id'],axis=1)

#fillNA

subject1 = subject1.fillna(subject1.mean())
subject2 = subject2.fillna(subject2.mean())
subject3 = subject3.fillna(subject3.mean())
subject4 = subject4.fillna(subject4.mean())

# %%
Accuracy0_array,Accuracy1_array, Accuracy2_array, Accuracy3_array = crossvalidate(subject1,subject2,subject3,subject4)
# Out:
# Leave subject 1 out
#
# Default model
#
#            |  PPos 	 PNeg 	 | Sums
# -------------------------------------
# actual pos |  888 	 0 	 | 888
# actual neg |  897 	 0 	 | 897
# -------------------------------------
# Sums       |  1785 	 0 	 | 1785
#    Accuracy  False Positive Rate  Precision  Recall  True Positive Rate
# 0  0.497479                  1.0   0.497479     1.0                 1.0
#
#
# Naives Bayes
#
#            |  PPos 	 PNeg 	 | Sums
# -------------------------------------
# actual pos |  387 	 501 	 | 888
# actual neg |  0 	 897 	 | 897
# -------------------------------------
# Sums       |  387 	 1398 	 | 1785
#    Accuracy  False Positive Rate  Precision    Recall  True Positive Rate
# 0  0.719328                  0.0        1.0  0.435811            0.435811
#
#
# Logistic regression
#
#            |  PPos 	 PNeg 	 | Sums
# -------------------------------------
# actual pos |  130 	 758 	 | 888
# actual neg |  12 	 885 	 | 897
# ...

# %%
N = 4
ind = np.arange(N)  # the x locations for the groups
width = 0.10       # the width of the bars

fig = plt.figure(figsize=(11,6))
plt.title('Normal vs. Aggressive Actions CV results')
ax = fig.add_subplot(111)

yvals = [Accuracy0_array[0], Accuracy0_array[1],Accuracy0_array[2], Accuracy0_array[3]]
rects1 = ax.bar(ind, yvals, width, color='skyblue')
zvals = [Accuracy1_array[0], Accuracy1_array[1],Accuracy1_array[2], Accuracy1_array[3]]
rects2 = ax.bar(ind+width, zvals, width, color='indianred')
kvals = [Accuracy2_array[0], Accuracy2_array[1],Accuracy2_array[2], Accuracy2_array[3]]
rects3 = ax.bar(ind+width*2, kvals, width, color='yellow')
xvals = [Accuracy3_array[0], Accuracy3_array[1],Accuracy3_array[2], Accuracy3_array[3]]
rects4 = ax.bar(ind+width*3, xvals, width, color='pink')

ax.set_ylabel('Accuracy at 0.5 threshold')
ax.set_xticks(ind+width)
ax.set_ylim([0,1.15])
ax.set_xticklabels( ('Leave Sub1/Fold 1', 'Leave Sub2/Fold 2', 'Leave Sub3/Fold 3', 'Leave Sub4/Fold 4') )
ax.legend( (rects1[0], rects2[0], rects3[0],rects4[0]), ('Default', 'Naive Bayes','Logistic Regression', 'Random Forests'), loc = 'upper right' )

# %%
features_remove_2 = ["last_location_of_maximum","last_location_of_minimum","length","number_crossing","partial_autocorrelation","range_count","set_property","value_count","variance_larger_than_standard_deviation"]

# %%
sub1_handshaking_features_2 = feature_space(sub1_handshaking_features,features_remove_2)
sub2_handshaking_features_2 = feature_space(sub2_handshaking_features,features_remove_2)
sub3_handshaking_features_2 = feature_space(sub3_handshaking_features,features_remove_2)
sub4_handshaking_features_2 = feature_space(sub3_handshaking_features,features_remove_2)

sub1_bowing_features_2 = feature_space(sub1_bowing_features,features_remove_2)
sub2_bowing_features_2 = feature_space(sub2_bowing_features,features_remove_2)
sub3_bowing_features_2 = feature_space(sub3_bowing_features,features_remove_2)
sub4_bowing_features_2 = feature_space(sub3_bowing_features,features_remove_2)

sub1_clapping_features_2 = feature_space(sub1_clapping_features,features_remove_2)
sub2_clapping_features_2 = feature_space(sub2_clapping_features,features_remove_2)
sub3_clapping_features_2 = feature_space(sub3_clapping_features,features_remove_2)
sub4_clapping_features_2 = feature_space(sub3_clapping_features,features_remove_2)

sub1_punching_features_2 = feature_space(sub1_punching_features,features_remove_2)
sub2_punching_features_2 = feature_space(sub2_punching_features,features_remove_2)
sub3_punching_features_2 = feature_space(sub3_punching_features,features_remove_2)
sub4_punching_features_2 = feature_space(sub3_punching_features,features_remove_2)

sub1_frontkicking_features_2 = feature_space(sub1_frontkicking_features,features_remove_2)
sub2_frontkicking_features_2 = feature_space(sub2_frontkicking_features,features_remove_2)
sub3_frontkicking_features_2 = feature_space(sub3_frontkicking_features,features_remove_2)
sub4_frontkicking_features_2 = feature_space(sub3_frontkicking_features,features_remove_2)

sub1_elbowing_features_2 = feature_space(sub1_elbowing_features,features_remove_2)
sub2_elbowing_features_2 = feature_space(sub2_elbowing_features,features_remove_2)
sub3_elbowing_features_2 = feature_space(sub3_elbowing_features,features_remove_2)
sub4_elbowing_features_2 = feature_space(sub3_elbowing_features,features_remove_2)

sub1_hammering_features_2 = feature_space(sub1_hammering_features,features_remove_2)
sub2_hammering_features_2 = feature_space(sub2_hammering_features,features_remove_2)
sub3_hammering_features_2 = feature_space(sub3_hammering_features,features_remove_2)
sub4_hammering_features_2 = feature_space(sub3_hammering_features,features_remove_2)

sub1_headering_features_2 = feature_space(sub1_headering_features,features_remove_2)
sub2_headering_features_2 = feature_space(sub2_headering_features,features_remove_2)
sub3_headering_features_2 = feature_space(sub3_headering_features,features_remove_2)
sub4_headering_features_2 = feature_space(sub3_headering_features,features_remove_2)

sub1_kneeing_features_2 = feature_space(sub1_kneeing_features,features_remove_2)
sub2_kneeing_features_2 = feature_space(sub2_kneeing_features,features_remove_2)
sub3_kneeing_features_2 = feature_space(sub3_kneeing_features,features_remove_2)
sub4_kneeing_features_2 = feature_space(sub3_kneeing_features,features_remove_2)

sub1_pulling_features_2 = feature_space(sub1_pulling_features,features_remove_2)
sub2_pulling_features_2 = feature_space(sub2_pulling_features,features_remove_2)
sub3_pulling_features_2 = feature_space(sub3_pulling_features,features_remove_2)
sub4_pulling_features_2 = feature_space(sub3_pulling_features,features_remove_2)

sub1_punching_features_2 = feature_space(sub1_punching_features,features_remove_2)
sub2_punching_features_2 = feature_space(sub2_punching_features,features_remove_2)
sub3_punching_features_2 = feature_space(sub3_punching_features,features_remove_2)
sub4_punching_features_2 = feature_space(sub3_punching_features,features_remove_2)

sub1_pushing_features_2 = feature_space(sub1_pushing_features,features_remove_2)
sub2_pushing_features_2 = feature_space(sub2_pushing_features,features_remove_2)
sub3_pushing_features_2 = feature_space(sub3_pushing_features,features_remove_2)
sub4_pushing_features_2 = feature_space(sub3_pushing_features,features_remove_2)

sub1_sidekicking_features_2 = feature_space(sub1_sidekicking_features,features_remove_2)
sub2_sidekicking_features_2 = feature_space(sub2_sidekicking_features,features_remove_2)
sub3_sidekicking_features_2 = feature_space(sub3_sidekicking_features,features_remove_2)
sub4_sidekicking_features_2 = feature_space(sub3_sidekicking_features,features_remove_2)

sub1_slapping_features_2 = feature_space(sub1_slapping_features,features_remove_2)
sub2_slapping_features_2 = feature_space(sub2_slapping_features,features_remove_2)
sub3_slapping_features_2 = feature_space(sub3_slapping_features,features_remove_2)
sub4_slapping_features_2 = feature_space(sub3_slapping_features,features_remove_2)

sub1_hugging_features_2 = feature_space(sub1_hugging_features,features_remove_2)
sub2_hugging_features_2 = feature_space(sub2_hugging_features,features_remove_2)
sub3_hugging_features_2 = feature_space(sub3_hugging_features,features_remove_2)
sub4_hugging_features_2 = feature_space(sub3_hugging_features,features_remove_2)

sub1_jumping_features_2 = feature_space(sub1_jumping_features,features_remove_2)
sub2_jumping_features_2 = feature_space(sub2_jumping_features,features_remove_2)
sub3_jumping_features_2 = feature_space(sub3_jumping_features,features_remove_2)
sub4_jumping_features_2 = feature_space(sub3_jumping_features,features_remove_2)

sub1_running_features_2 = feature_space(sub1_running_features,features_remove_2)
sub2_running_features_2 = feature_space(sub2_running_features,features_remove_2)
sub3_running_features_2 = feature_space(sub3_running_features,features_remove_2)
sub4_running_features_2 = feature_space(sub3_running_features,features_remove_2)

sub1_seating_features_2 = feature_space(sub1_seating_features,features_remove_2)
sub2_seating_features_2 = feature_space(sub2_seating_features,features_remove_2)
sub3_seating_features_2 = feature_space(sub3_seating_features,features_remove_2)
sub4_seating_features_2 = feature_space(sub3_seating_features,features_remove_2)

sub1_standing_features_2 = feature_space(sub1_standing_features,features_remove_2)
sub2_standing_features_2 = feature_space(sub2_standing_features,features_remove_2)
sub3_standing_features_2 = feature_space(sub3_standing_features,features_remove_2)
sub4_standing_features_2 = feature_space(sub3_standing_features,features_remove_2)

sub1_walking_features_2 = feature_space(sub1_walking_features,features_remove_2)
sub2_walking_features_2 = feature_space(sub2_walking_features,features_remove_2)
sub3_walking_features_2 = feature_space(sub3_walking_features,features_remove_2)
sub4_walking_features_2 = feature_space(sub3_walking_features,features_remove_2)

sub1_waving_features_2 = feature_space(sub1_waving_features,features_remove_2)
sub2_waving_features_2 = feature_space(sub2_waving_features,features_remove_2)
sub3_waving_features_2 = feature_space(sub3_waving_features,features_remove_2)
sub4_waving_features_2 = feature_space(sub3_waving_features,features_remove_2)

# %%
subject1 = pd.concat([sub1_handshaking_features_2,sub1_punching_features_2,sub1_seating_features_2,sub1_standing_features_2,sub1_pushing_features_2,sub1_pulling_features_2,sub1_slapping_features_2,sub1_sidekicking_features_2,sub1_frontkicking_features_2,sub1_kneeing_features_2,sub1_hammering_features_2, sub1_hugging_features_2,sub1_headering_features_2,sub1_jumping_features_2,sub1_bowing_features_2,sub1_elbowing_features_2,sub1_running_features_2,sub1_walking_features_2,sub1_clapping_features_2,sub1_waving_features_2])
subject2 = pd.concat([sub2_handshaking_features_2,sub2_punching_features_2,sub2_seating_features_2,sub2_standing_features_2,sub2_pushing_features_2,sub2_pulling_features_2,sub2_slapping_features_2,sub2_sidekicking_features_2,sub2_frontkicking_features_2,sub2_kneeing_features_2,sub2_hammering_features_2, sub2_hugging_features_2,sub2_headering_features_2,sub2_jumping_features_2,sub2_bowing_features_2,sub2_elbowing_features_2,sub2_running_features_2,sub2_walking_features_2,sub2_clapping_features_2,sub2_waving_features_2])
subject3 = pd.concat([sub3_handshaking_features_2,sub3_punching_features_2,sub3_seating_features_2,sub3_standing_features_2,sub3_pushing_features_2,sub3_pulling_features_2,sub3_slapping_features_2,sub3_sidekicking_features_2,sub3_frontkicking_features_2,sub3_kneeing_features_2,sub3_hammering_features_2, sub3_hugging_features_2,sub3_headering_features_2,sub3_jumping_features_2,sub3_bowing_features_2,sub3_elbowing_features_2,sub3_running_features_2,sub3_walking_features_2,sub3_clapping_features_2,sub3_waving_features_2])
subject4 = pd.concat([sub4_handshaking_features_2,sub4_punching_features_2,sub4_seating_features_2,sub4_standing_features_2,sub4_pushing_features_2,sub4_pulling_features_2,sub4_slapping_features_2,sub4_sidekicking_features_2,sub4_frontkicking_features_2,sub4_kneeing_features_2,sub4_hammering_features_2, sub4_hugging_features_2,sub4_headering_features_2,sub4_jumping_features_2,sub4_bowing_features_2,sub4_elbowing_features_2,sub4_running_features_2,sub4_walking_features_2,sub4_clapping_features_2,sub4_waving_features_2])

# %%
#DROP ID column

subject1 = subject1.drop(['id'],axis=1)
subject2 = subject2.drop(['id'],axis=1)
subject3 = subject3.drop(['id'],axis=1)
subject4 = subject4.drop(['id'],axis=1)

subject1 = subject1.fillna(subject1.mean())
subject2 = subject2.fillna(subject2.mean())
subject3 = subject3.fillna(subject3.mean())
subject4 = subject4.fillna(subject4.mean())

# %%
Accuracy0_array,Accuracy1_array, Accuracy2_array, Accuracy3_array = crossvalidate(subject1,subject2,subject3,subject4)
# Out:
# Leave subject 1 out
#
# Default model
#
#            |  PPos 	 PNeg 	 | Sums
# -------------------------------------
# actual pos |  888 	 0 	 | 888
# actual neg |  897 	 0 	 | 897
# -------------------------------------
# Sums       |  1785 	 0 	 | 1785
#    Accuracy  False Positive Rate  Precision  Recall  True Positive Rate
# 0  0.497479                  1.0   0.497479     1.0                 1.0
#
#
# Naives Bayes
#
#            |  PPos 	 PNeg 	 | Sums
# -------------------------------------
# actual pos |  181 	 707 	 | 888
# actual neg |  8 	 889 	 | 897
# -------------------------------------
# Sums       |  189 	 1596 	 | 1785
#    Accuracy  False Positive Rate  Precision    Recall  True Positive Rate
# 0   0.59944             0.008919   0.957672  0.203829            0.203829
#
#
# Logistic regression
#
#            |  PPos 	 PNeg 	 | Sums
# -------------------------------------
# actual pos |  227 	 661 	 | 888
# actual neg |  129 	 768 	 | 897
# ...

# %%
N = 4
ind = np.arange(N)  # the x locations for the groups
width = 0.10       # the width of the bars

fig = plt.figure(figsize=(11,6))
plt.title('Normal vs. Aggressive Actions CV results')
ax = fig.add_subplot(111)

yvals = [Accuracy0_array[0], Accuracy0_array[1],Accuracy0_array[2], Accuracy0_array[3]]
rects1 = ax.bar(ind, yvals, width, color='skyblue')
zvals = [Accuracy1_array[0], Accuracy1_array[1],Accuracy1_array[2], Accuracy1_array[3]]
rects2 = ax.bar(ind+width, zvals, width, color='indianred')
kvals = [Accuracy2_array[0], Accuracy2_array[1],Accuracy2_array[2], Accuracy2_array[3]]
rects3 = ax.bar(ind+width*2, kvals, width, color='yellow')
xvals = [Accuracy3_array[0], Accuracy3_array[1],Accuracy3_array[2], Accuracy3_array[3]]
rects4 = ax.bar(ind+width*3, xvals, width, color='pink')

ax.set_ylabel('Accuracy at 0.5 threshold')
ax.set_xticks(ind+width)
ax.set_ylim([0,1.15])
ax.set_xticklabels( ('Leave Sub1/Fold 1', 'Leave Sub2/Fold 2', 'Leave Sub3/Fold 3', 'Leave Sub4/Fold 4') )
ax.legend( (rects1[0], rects2[0], rects3[0],rects4[0]), ('Default', 'Naive Bayes','Logistic Regression', 'Random Forests'), loc = 'upper right' )

# %%
features_remove_3 = ["augmented_dickey_fuller","agg_autocorrelation","energy_ratio_by_chunks","has_duplicate","has_diplicate_max","friedrich_coefficients","index_mass_quantile","max_langevin_fixed_point","sum_of_reoccuring_values","ratio_value_number_to_time_series_length","last_location_of_maximum","last_location_of_minimum","length","number_crossing","partial_autocorrelation","range_count","set_property","value_count","variance_larger_than_standard_deviation"]

# %%
sub1_handshaking_features_3 = feature_space(sub1_handshaking_features,features_remove_3)
sub2_handshaking_features_3 = feature_space(sub2_handshaking_features,features_remove_3)
sub3_handshaking_features_3 = feature_space(sub3_handshaking_features,features_remove_3)
sub4_handshaking_features_3 = feature_space(sub3_handshaking_features,features_remove_3)

sub1_bowing_features_3 = feature_space(sub1_bowing_features,features_remove_3)
sub2_bowing_features_3 = feature_space(sub2_bowing_features,features_remove_3)
sub3_bowing_features_3 = feature_space(sub3_bowing_features,features_remove_3)
sub4_bowing_features_3 = feature_space(sub3_bowing_features,features_remove_3)

sub1_clapping_features_3 = feature_space(sub1_clapping_features,features_remove_3)
sub2_clapping_features_3 = feature_space(sub2_clapping_features,features_remove_3)
sub3_clapping_features_3 = feature_space(sub3_clapping_features,features_remove_3)
sub4_clapping_features_3 = feature_space(sub3_clapping_features,features_remove_3)

sub1_punching_features_3 = feature_space(sub1_punching_features,features_remove_3)
sub2_punching_features_3 = feature_space(sub2_punching_features,features_remove_3)
sub3_punching_features_3 = feature_space(sub3_punching_features,features_remove_3)
sub4_punching_features_3 = feature_space(sub3_punching_features,features_remove_3)

sub1_frontkicking_features_3 = feature_space(sub1_frontkicking_features,features_remove_3)
sub2_frontkicking_features_3 = feature_space(sub2_frontkicking_features,features_remove_3)
sub3_frontkicking_features_3 = feature_space(sub3_frontkicking_features,features_remove_3)
sub4_frontkicking_features_3 = feature_space(sub3_frontkicking_features,features_remove_3)

sub1_elbowing_features_3 = feature_space(sub1_elbowing_features,features_remove_3)
sub2_elbowing_features_3 = feature_space(sub2_elbowing_features,features_remove_3)
sub3_elbowing_features_3 = feature_space(sub3_elbowing_features,features_remove_3)
sub4_elbowing_features_3 = feature_space(sub3_elbowing_features,features_remove_3)

sub1_hammering_features_3 = feature_space(sub1_hammering_features,features_remove_3)
sub2_hammering_features_3 = feature_space(sub2_hammering_features,features_remove_3)
sub3_hammering_features_3 = feature_space(sub3_hammering_features,features_remove_3)
sub4_hammering_features_3 = feature_space(sub3_hammering_features,features_remove_3)

sub1_headering_features_3 = feature_space(sub1_headering_features,features_remove_3)
sub2_headering_features_3 = feature_space(sub2_headering_features,features_remove_3)
sub3_headering_features_3 = feature_space(sub3_headering_features,features_remove_3)
sub4_headering_features_3 = feature_space(sub3_headering_features,features_remove_3)

sub1_kneeing_features_3 = feature_space(sub1_kneeing_features,features_remove_3)
sub2_kneeing_features_3 = feature_space(sub2_kneeing_features,features_remove_3)
sub3_kneeing_features_3 = feature_space(sub3_kneeing_features,features_remove_3)
sub4_kneeing_features_3 = feature_space(sub3_kneeing_features,features_remove_3)

sub1_pulling_features_3 = feature_space(sub1_pulling_features,features_remove_3)
sub2_pulling_features_3 = feature_space(sub2_pulling_features,features_remove_3)
sub3_pulling_features_3 = feature_space(sub3_pulling_features,features_remove_3)
sub4_pulling_features_3 = feature_space(sub3_pulling_features,features_remove_3)

sub1_punching_features_3 = feature_space(sub1_punching_features,features_remove_3)
sub2_punching_features_3 = feature_space(sub2_punching_features,features_remove_3)
sub3_punching_features_3 = feature_space(sub3_punching_features,features_remove_3)
sub4_punching_features_3 = feature_space(sub3_punching_features,features_remove_3)

sub1_pushing_features_3 = feature_space(sub1_pushing_features,features_remove_3)
sub2_pushing_features_3 = feature_space(sub2_pushing_features,features_remove_3)
sub3_pushing_features_3 = feature_space(sub3_pushing_features,features_remove_3)
sub4_pushing_features_3 = feature_space(sub3_pushing_features,features_remove_3)

sub1_sidekicking_features_3 = feature_space(sub1_sidekicking_features,features_remove_3)
sub2_sidekicking_features_3 = feature_space(sub2_sidekicking_features,features_remove_3)
sub3_sidekicking_features_3 = feature_space(sub3_sidekicking_features,features_remove_3)
sub4_sidekicking_features_3 = feature_space(sub3_sidekicking_features,features_remove_3)

sub1_slapping_features_3 = feature_space(sub1_slapping_features,features_remove_3)
sub2_slapping_features_3 = feature_space(sub2_slapping_features,features_remove_3)
sub3_slapping_features_3 = feature_space(sub3_slapping_features,features_remove_3)
sub4_slapping_features_3 = feature_space(sub3_slapping_features,features_remove_3)

sub1_hugging_features_3 = feature_space(sub1_hugging_features,features_remove_3)
sub2_hugging_features_3 = feature_space(sub2_hugging_features,features_remove_3)
sub3_hugging_features_3 = feature_space(sub3_hugging_features,features_remove_3)
sub4_hugging_features_3 = feature_space(sub3_hugging_features,features_remove_3)

sub1_jumping_features_3 = feature_space(sub1_jumping_features,features_remove_3)
sub2_jumping_features_3 = feature_space(sub2_jumping_features,features_remove_3)
sub3_jumping_features_3 = feature_space(sub3_jumping_features,features_remove_3)
sub4_jumping_features_3 = feature_space(sub3_jumping_features,features_remove_3)

sub1_running_features_3 = feature_space(sub1_running_features,features_remove_3)
sub2_running_features_3 = feature_space(sub2_running_features,features_remove_3)
sub3_running_features_3 = feature_space(sub3_running_features,features_remove_3)
sub4_running_features_3 = feature_space(sub3_running_features,features_remove_3)

sub1_seating_features_3 = feature_space(sub1_seating_features,features_remove_3)
sub2_seating_features_3 = feature_space(sub2_seating_features,features_remove_3)
sub3_seating_features_3 = feature_space(sub3_seating_features,features_remove_3)
sub4_seating_features_3 = feature_space(sub3_seating_features,features_remove_3)

sub1_standing_features_3 = feature_space(sub1_standing_features,features_remove_3)
sub2_standing_features_3 = feature_space(sub2_standing_features,features_remove_3)
sub3_standing_features_3 = feature_space(sub3_standing_features,features_remove_3)
sub4_standing_features_3 = feature_space(sub3_standing_features,features_remove_3)

sub1_walking_features_3 = feature_space(sub1_walking_features,features_remove_3)
sub2_walking_features_3 = feature_space(sub2_walking_features,features_remove_3)
sub3_walking_features_3 = feature_space(sub3_walking_features,features_remove_3)
sub4_walking_features_3 = feature_space(sub3_walking_features,features_remove_3)

sub1_waving_features_3 = feature_space(sub1_waving_features,features_remove_3)
sub2_waving_features_3 = feature_space(sub2_waving_features,features_remove_3)
sub3_waving_features_3 = feature_space(sub3_waving_features,features_remove_3)
sub4_waving_features_3 = feature_space(sub3_waving_features,features_remove_3)

# %%
subject1 = pd.concat([sub1_handshaking_features_3,sub1_punching_features_3,sub1_seating_features_3,sub1_standing_features_3,sub1_pushing_features_3,sub1_pulling_features_3,sub1_slapping_features_3,sub1_sidekicking_features_3,sub1_frontkicking_features_3,sub1_kneeing_features_3,sub1_hammering_features_3, sub1_hugging_features_3,sub1_headering_features_3,sub1_jumping_features_3,sub1_bowing_features_3,sub1_elbowing_features_3,sub1_running_features_3,sub1_walking_features_3,sub1_clapping_features_3,sub1_waving_features_3])
subject2 = pd.concat([sub2_handshaking_features_3,sub2_punching_features_3,sub2_seating_features_3,sub2_standing_features_3,sub2_pushing_features_3,sub2_pulling_features_3,sub2_slapping_features_3,sub2_sidekicking_features_3,sub2_frontkicking_features_3,sub2_kneeing_features_3,sub2_hammering_features_3, sub2_hugging_features_3,sub2_headering_features_3,sub2_jumping_features_3,sub2_bowing_features_3,sub2_elbowing_features_3,sub2_running_features_3,sub2_walking_features_3,sub2_clapping_features_3,sub2_waving_features_3])
subject3 = pd.concat([sub3_handshaking_features_3,sub3_punching_features_3,sub3_seating_features_3,sub3_standing_features_3,sub3_pushing_features_3,sub3_pulling_features_3,sub3_slapping_features_3,sub3_sidekicking_features_3,sub3_frontkicking_features_3,sub3_kneeing_features_3,sub3_hammering_features_3, sub3_hugging_features_3,sub3_headering_features_3,sub3_jumping_features_3,sub3_bowing_features_3,sub3_elbowing_features_3,sub3_running_features_3,sub3_walking_features_3,sub3_clapping_features_3,sub3_waving_features_3])
subject4 = pd.concat([sub4_handshaking_features_3,sub4_punching_features_3,sub4_seating_features_3,sub4_standing_features_3,sub4_pushing_features_3,sub4_pulling_features_3,sub4_slapping_features_3,sub4_sidekicking_features_3,sub4_frontkicking_features_3,sub4_kneeing_features_3,sub4_hammering_features_3, sub4_hugging_features_3,sub4_headering_features_3,sub4_jumping_features_3,sub4_bowing_features_3,sub4_elbowing_features_3,sub4_running_features_3,sub4_walking_features_3,sub4_clapping_features_3,sub4_waving_features_3])

# %%
#DROP ID column

subject1 = subject1.drop(['id'],axis=1)
subject2 = subject2.drop(['id'],axis=1)
subject3 = subject3.drop(['id'],axis=1)
subject4 = subject4.drop(['id'],axis=1)

subject1 = subject1.fillna(subject1.mean())
subject2 = subject2.fillna(subject2.mean())
subject3 = subject3.fillna(subject3.mean())
subject4 = subject4.fillna(subject4.mean())

# %%
Accuracy0_array,Accuracy1_array, Accuracy2_array, Accuracy3_array = crossvalidate(subject1,subject2,subject3,subject4)

# %%
N = 4
ind = np.arange(N)  # the x locations for the groups
width = 0.10       # the width of the bars

fig = plt.figure(figsize=(11,6))
plt.title('Normal vs. Aggressive Actions CV results')
ax = fig.add_subplot(111)

yvals = [Accuracy0_array[0], Accuracy0_array[1],Accuracy0_array[2], Accuracy0_array[3]]
rects1 = ax.bar(ind, yvals, width, color='skyblue')
zvals = [Accuracy1_array[0], Accuracy1_array[1],Accuracy1_array[2], Accuracy1_array[3]]
rects2 = ax.bar(ind+width, zvals, width, color='indianred')
kvals = [Accuracy2_array[0], Accuracy2_array[1],Accuracy2_array[2], Accuracy2_array[3]]
rects3 = ax.bar(ind+width*2, kvals, width, color='yellow')
xvals = [Accuracy3_array[0], Accuracy3_array[1],Accuracy3_array[2], Accuracy3_array[3]]
rects4 = ax.bar(ind+width*3, xvals, width, color='pink')

ax.set_ylabel('Accuracy at 0.5 threshold')
ax.set_xticks(ind+width)
ax.set_ylim([0,1.15])
ax.set_xticklabels( ('Leave Sub1/Fold 1', 'Leave Sub2/Fold 2', 'Leave Sub3/Fold 3', 'Leave Sub4/Fold 4') )
ax.legend( (rects1[0], rects2[0], rects3[0],rects4[0]), ('Default', 'Naive Bayes','Logistic Regression', 'Random Forests'), loc = 'upper right' )

# %%
features_remove_4 = ["lag","ar_coefficient","mean_second_derivative_central","time_reversal_asymmetry_statistic","last_location_of_maximum","last_location_of_minimum","length","number_crossing","partial_autocorrelation","range_count","set_property","value_count","variance_larger_than_standard_deviation"]

# %%
sub1_handshaking_features_4 = feature_space(sub1_handshaking_features,features_remove_4)
sub2_handshaking_features_4 = feature_space(sub2_handshaking_features,features_remove_4)
sub3_handshaking_features_4 = feature_space(sub3_handshaking_features,features_remove_4)
sub4_handshaking_features_4 = feature_space(sub3_handshaking_features,features_remove_4)

sub1_bowing_features_4 = feature_space(sub1_bowing_features,features_remove_4)
sub2_bowing_features_4 = feature_space(sub2_bowing_features,features_remove_4)
sub3_bowing_features_4 = feature_space(sub3_bowing_features,features_remove_4)
sub4_bowing_features_4 = feature_space(sub3_bowing_features,features_remove_4)

sub1_clapping_features_4 = feature_space(sub1_clapping_features,features_remove_4)
sub2_clapping_features_4 = feature_space(sub2_clapping_features,features_remove_4)
sub3_clapping_features_4 = feature_space(sub3_clapping_features,features_remove_4)
sub4_clapping_features_4 = feature_space(sub3_clapping_features,features_remove_4)

sub1_punching_features_4 = feature_space(sub1_punching_features,features_remove_4)
sub2_punching_features_4 = feature_space(sub2_punching_features,features_remove_4)
sub3_punching_features_4 = feature_space(sub3_punching_features,features_remove_4)
sub4_punching_features_4 = feature_space(sub3_punching_features,features_remove_4)

sub1_frontkicking_features_4 = feature_space(sub1_frontkicking_features,features_remove_4)
sub2_frontkicking_features_4 = feature_space(sub2_frontkicking_features,features_remove_4)
sub3_frontkicking_features_4 = feature_space(sub3_frontkicking_features,features_remove_4)
sub4_frontkicking_features_4 = feature_space(sub3_frontkicking_features,features_remove_4)

sub1_elbowing_features_4 = feature_space(sub1_elbowing_features,features_remove_4)
sub2_elbowing_features_4 = feature_space(sub2_elbowing_features,features_remove_4)
sub3_elbowing_features_4 = feature_space(sub3_elbowing_features,features_remove_4)
sub4_elbowing_features_4 = feature_space(sub3_elbowing_features,features_remove_4)

sub1_hammering_features_4 = feature_space(sub1_hammering_features,features_remove_4)
sub2_hammering_features_4 = feature_space(sub2_hammering_features,features_remove_4)
sub3_hammering_features_4 = feature_space(sub3_hammering_features,features_remove_4)
sub4_hammering_features_4 = feature_space(sub3_hammering_features,features_remove_4)

sub1_headering_features_4 = feature_space(sub1_headering_features,features_remove_4)
sub2_headering_features_4 = feature_space(sub2_headering_features,features_remove_4)
sub3_headering_features_4 = feature_space(sub3_headering_features,features_remove_4)
sub4_headering_features_4 = feature_space(sub3_headering_features,features_remove_4)

sub1_kneeing_features_4 = feature_space(sub1_kneeing_features,features_remove_4)
sub2_kneeing_features_4 = feature_space(sub2_kneeing_features,features_remove_4)
sub3_kneeing_features_4 = feature_space(sub3_kneeing_features,features_remove_4)
sub4_kneeing_features_4 = feature_space(sub3_kneeing_features,features_remove_4)

sub1_pulling_features_4 = feature_space(sub1_pulling_features,features_remove_4)
sub2_pulling_features_4 = feature_space(sub2_pulling_features,features_remove_4)
sub3_pulling_features_4 = feature_space(sub3_pulling_features,features_remove_4)
sub4_pulling_features_4 = feature_space(sub3_pulling_features,features_remove_4)

sub1_punching_features_4 = feature_space(sub1_punching_features,features_remove_4)
sub2_punching_features_4 = feature_space(sub2_punching_features,features_remove_4)
sub3_punching_features_4 = feature_space(sub3_punching_features,features_remove_4)
sub4_punching_features_4 = feature_space(sub3_punching_features,features_remove_4)

sub1_pushing_features_4 = feature_space(sub1_pushing_features,features_remove_4)
sub2_pushing_features_4 = feature_space(sub2_pushing_features,features_remove_4)
sub3_pushing_features_4 = feature_space(sub3_pushing_features,features_remove_4)
sub4_pushing_features_4 = feature_space(sub3_pushing_features,features_remove_4)

sub1_sidekicking_features_4 = feature_space(sub1_sidekicking_features,features_remove_4)
sub2_sidekicking_features_4 = feature_space(sub2_sidekicking_features,features_remove_4)
sub3_sidekicking_features_4 = feature_space(sub3_sidekicking_features,features_remove_4)
sub4_sidekicking_features_4 = feature_space(sub3_sidekicking_features,features_remove_4)

sub1_slapping_features_4 = feature_space(sub1_slapping_features,features_remove_4)
sub2_slapping_features_4 = feature_space(sub2_slapping_features,features_remove_4)
sub3_slapping_features_4 = feature_space(sub3_slapping_features,features_remove_4)
sub4_slapping_features_4 = feature_space(sub3_slapping_features,features_remove_4)

sub1_hugging_features_4 = feature_space(sub1_hugging_features,features_remove_4)
sub2_hugging_features_4 = feature_space(sub2_hugging_features,features_remove_4)
sub3_hugging_features_4 = feature_space(sub3_hugging_features,features_remove_4)
sub4_hugging_features_4 = feature_space(sub3_hugging_features,features_remove_4)

sub1_jumping_features_4 = feature_space(sub1_jumping_features,features_remove_4)
sub2_jumping_features_4 = feature_space(sub2_jumping_features,features_remove_4)
sub3_jumping_features_4 = feature_space(sub3_jumping_features,features_remove_4)
sub4_jumping_features_4 = feature_space(sub3_jumping_features,features_remove_4)

sub1_running_features_4 = feature_space(sub1_running_features,features_remove_4)
sub2_running_features_4 = feature_space(sub2_running_features,features_remove_4)
sub3_running_features_4 = feature_space(sub3_running_features,features_remove_4)
sub4_running_features_4 = feature_space(sub3_running_features,features_remove_4)

sub1_seating_features_4 = feature_space(sub1_seating_features,features_remove_4)
sub2_seating_features_4 = feature_space(sub2_seating_features,features_remove_4)
sub3_seating_features_4 = feature_space(sub3_seating_features,features_remove_4)
sub4_seating_features_4 = feature_space(sub3_seating_features,features_remove_4)

sub1_standing_features_4 = feature_space(sub1_standing_features,features_remove_4)
sub2_standing_features_4 = feature_space(sub2_standing_features,features_remove_4)
sub3_standing_features_4 = feature_space(sub3_standing_features,features_remove_4)
sub4_standing_features_4 = feature_space(sub3_standing_features,features_remove_4)

sub1_walking_features_4 = feature_space(sub1_walking_features,features_remove_4)
sub2_walking_features_4 = feature_space(sub2_walking_features,features_remove_4)
sub3_walking_features_4 = feature_space(sub3_walking_features,features_remove_4)
sub4_walking_features_4 = feature_space(sub3_walking_features,features_remove_4)

sub1_waving_features_4 = feature_space(sub1_waving_features,features_remove_4)
sub2_waving_features_4 = feature_space(sub2_waving_features,features_remove_4)
sub3_waving_features_4 = feature_space(sub3_waving_features,features_remove_4)
sub4_waving_features_4 = feature_space(sub3_waving_features,features_remove_4)

# %%
subject1 = pd.concat([sub1_handshaking_features_4,sub1_punching_features_4,sub1_seating_features_4,sub1_standing_features_4,sub1_pushing_features_4,sub1_pulling_features_4,sub1_slapping_features_4,sub1_sidekicking_features_4,sub1_frontkicking_features_4,sub1_kneeing_features_4,sub1_hammering_features_4, sub1_hugging_features_4,sub1_headering_features_4,sub1_jumping_features_4,sub1_bowing_features_4,sub1_elbowing_features_4,sub1_running_features_4,sub1_walking_features_4,sub1_clapping_features_4,sub1_waving_features_4])
subject2 = pd.concat([sub2_handshaking_features_4,sub2_punching_features_4,sub2_seating_features_4,sub2_standing_features_4,sub2_pushing_features_4,sub2_pulling_features_4,sub2_slapping_features_4,sub2_sidekicking_features_4,sub2_frontkicking_features_4,sub2_kneeing_features_4,sub2_hammering_features_4, sub2_hugging_features_4,sub2_headering_features_4,sub2_jumping_features_4,sub2_bowing_features_4,sub2_elbowing_features_4,sub2_running_features_4,sub2_walking_features_4,sub2_clapping_features_4,sub2_waving_features_4])
subject3 = pd.concat([sub3_handshaking_features_4,sub3_punching_features_4,sub3_seating_features_4,sub3_standing_features_4,sub3_pushing_features_4,sub3_pulling_features_4,sub3_slapping_features_4,sub3_sidekicking_features_4,sub3_frontkicking_features_4,sub3_kneeing_features_4,sub3_hammering_features_4, sub3_hugging_features_4,sub3_headering_features_4,sub3_jumping_features_4,sub3_bowing_features_4,sub3_elbowing_features_4,sub3_running_features_4,sub3_walking_features_4,sub3_clapping_features_4,sub3_waving_features_4])
subject4 = pd.concat([sub4_handshaking_features_4,sub4_punching_features_4,sub4_seating_features_4,sub4_standing_features_4,sub4_pushing_features_4,sub4_pulling_features_4,sub4_slapping_features_4,sub4_sidekicking_features_4,sub4_frontkicking_features_4,sub4_kneeing_features_4,sub4_hammering_features_4, sub4_hugging_features_4,sub4_headering_features_4,sub4_jumping_features_4,sub4_bowing_features_4,sub4_elbowing_features_4,sub4_running_features_4,sub4_walking_features_4,sub4_clapping_features_4,sub4_waving_features_4])

# %%
#DROP ID column

subject1 = subject1.drop(['id'],axis=1)
subject2 = subject2.drop(['id'],axis=1)
subject3 = subject3.drop(['id'],axis=1)
subject4 = subject4.drop(['id'],axis=1)

subject1 = subject1.fillna(subject1.mean())
subject2 = subject2.fillna(subject2.mean())
subject3 = subject3.fillna(subject3.mean())
subject4 = subject4.fillna(subject4.mean())

# %%
Accuracy0_array,Accuracy1_array, Accuracy2_array, Accuracy3_array = crossvalidate(subject1,subject2,subject3,subject4)
# Out:
# Leave subject 1 out
#
# Default model
#
#            |  PPos 	 PNeg 	 | Sums
# -------------------------------------
# actual pos |  888 	 0 	 | 888
# actual neg |  897 	 0 	 | 897
# -------------------------------------
# Sums       |  1785 	 0 	 | 1785
#    Accuracy  False Positive Rate  Precision  Recall  True Positive Rate
# 0  0.497479                  1.0   0.497479     1.0                 1.0
#
#
# Naives Bayes
#
#            |  PPos 	 PNeg 	 | Sums
# -------------------------------------
# actual pos |  823 	 65 	 | 888
# actual neg |  48 	 849 	 | 897
# -------------------------------------
# Sums       |  871 	 914 	 | 1785
#    Accuracy  False Positive Rate  Precision    Recall  True Positive Rate
# 0  0.936695             0.053512   0.944891  0.926802            0.926802
#
#
# Logistic regression
#
#            |  PPos 	 PNeg 	 | Sums
# -------------------------------------
# actual pos |  611 	 277 	 | 888
# actual neg |  7 	 890 	 | 897
# ...

# %%
N = 4
ind = np.arange(N)  # the x locations for the groups
width = 0.10       # the width of the bars

fig = plt.figure(figsize=(11,6))
plt.title('Normal vs. Aggressive Actions CV results')
ax = fig.add_subplot(111)

yvals = [Accuracy0_array[0], Accuracy0_array[1],Accuracy0_array[2], Accuracy0_array[3]]
rects1 = ax.bar(ind, yvals, width, color='skyblue')
zvals = [Accuracy1_array[0], Accuracy1_array[1],Accuracy1_array[2], Accuracy1_array[3]]
rects2 = ax.bar(ind+width, zvals, width, color='indianred')
kvals = [Accuracy2_array[0], Accuracy2_array[1],Accuracy2_array[2], Accuracy2_array[3]]
rects3 = ax.bar(ind+width*2, kvals, width, color='yellow')
xvals = [Accuracy3_array[0], Accuracy3_array[1],Accuracy3_array[2], Accuracy3_array[3]]
rects4 = ax.bar(ind+width*3, xvals, width, color='pink')

ax.set_ylabel('Accuracy at 0.5 threshold')
ax.set_xticks(ind+width)
ax.set_ylim([0,1.3])
ax.set_xticklabels( ('Leave Sub1/Fold 1', 'Leave Sub2/Fold 2', 'Leave Sub3/Fold 3', 'Leave Sub4/Fold 4') )
ax.legend( (rects1[0], rects2[0], rects3[0],rects4[0]), ('Default', 'Naive Bayes','Logistic Regression', 'Random Forests'), loc = 'upper right' )

# %%
entire_data = pd.concat([subject1, subject2, subject3, subject4])
n,m = entire_data.shape # number of rows and columns
X = entire_data.iloc[:,:m-1]# get training input data
y = entire_data.iloc[:,m-1]

#Standardizing
scaler = preprocessing.StandardScaler().fit(X)
X_scaled = scaler.transform(X)                           
X_scaled = pd.DataFrame(X_scaled)
X_scaled.columns = X.columns
X = X_scaled

rf = RandomForestClassifier(n_estimators = 100)
rf.fit(X,y)
feature_importances = pd.DataFrame(rf.feature_importances_,
                                   index = X.columns,
                                    columns=['importance']).sort_values('importance', ascending=False)
display(feature_importances)

# %%
features_remove_5 = ["augmented_dickey_fuller","agg_autocorrelation","energy_ratio_by_chunks","has_duplicate","has_duplicate_max","friedrich_coefficients","index_mass_quantile","max_langevin_fixed_point","sum_of_reoccuring_values","ratio_value_number_to_time_series_length","last_location_of_maximum","last_location_of_minimum","length","number_crossing","partial_autocorrelation","range_count","set_property","value_count","variance_larger_than_standard_deviation","lag","ar_coefficient","mean_second_derivative_central","time_reversal_asymmetry_statistic","last_location_of_maximum","last_location_of_minimum","length","number_crossing","partial_autocorrelation","range_count","set_property","value_count","variance_larger_than_standard_deviation"]

# %%
sub1_handshaking_features_5 = feature_space(sub1_handshaking_features,features_remove_5)
sub2_handshaking_features_5 = feature_space(sub2_handshaking_features,features_remove_5)
sub3_handshaking_features_5 = feature_space(sub3_handshaking_features,features_remove_5)
sub4_handshaking_features_5 = feature_space(sub3_handshaking_features,features_remove_5)

sub1_bowing_features_5 = feature_space(sub1_bowing_features,features_remove_5)
sub2_bowing_features_5 = feature_space(sub2_bowing_features,features_remove_5)
sub3_bowing_features_5 = feature_space(sub3_bowing_features,features_remove_5)
sub4_bowing_features_5 = feature_space(sub3_bowing_features,features_remove_5)

sub1_clapping_features_5 = feature_space(sub1_clapping_features,features_remove_5)
sub2_clapping_features_5 = feature_space(sub2_clapping_features,features_remove_5)
sub3_clapping_features_5 = feature_space(sub3_clapping_features,features_remove_5)
sub4_clapping_features_5 = feature_space(sub3_clapping_features,features_remove_5)

sub1_punching_features_5 = feature_space(sub1_punching_features,features_remove_5)
sub2_punching_features_5 = feature_space(sub2_punching_features,features_remove_5)
sub3_punching_features_5 = feature_space(sub3_punching_features,features_remove_5)
sub4_punching_features_5 = feature_space(sub3_punching_features,features_remove_5)

sub1_frontkicking_features_5 = feature_space(sub1_frontkicking_features,features_remove_5)
sub2_frontkicking_features_5 = feature_space(sub2_frontkicking_features,features_remove_5)
sub3_frontkicking_features_5 = feature_space(sub3_frontkicking_features,features_remove_5)
sub4_frontkicking_features_5 = feature_space(sub3_frontkicking_features,features_remove_5)

sub1_elbowing_features_5 = feature_space(sub1_elbowing_features,features_remove_5)
sub2_elbowing_features_5 = feature_space(sub2_elbowing_features,features_remove_5)
sub3_elbowing_features_5 = feature_space(sub3_elbowing_features,features_remove_5)
sub4_elbowing_features_5 = feature_space(sub3_elbowing_features,features_remove_5)

sub1_hammering_features_5 = feature_space(sub1_hammering_features,features_remove_5)
sub2_hammering_features_5 = feature_space(sub2_hammering_features,features_remove_5)
sub3_hammering_features_5 = feature_space(sub3_hammering_features,features_remove_5)
sub4_hammering_features_5 = feature_space(sub3_hammering_features,features_remove_5)

sub1_headering_features_5 = feature_space(sub1_headering_features,features_remove_5)
sub2_headering_features_5 = feature_space(sub2_headering_features,features_remove_5)
sub3_headering_features_5 = feature_space(sub3_headering_features,features_remove_5)
sub4_headering_features_5 = feature_space(sub3_headering_features,features_remove_5)

sub1_kneeing_features_5 = feature_space(sub1_kneeing_features,features_remove_5)
sub2_kneeing_features_5 = feature_space(sub2_kneeing_features,features_remove_5)
sub3_kneeing_features_5 = feature_space(sub3_kneeing_features,features_remove_5)
sub4_kneeing_features_5 = feature_space(sub3_kneeing_features,features_remove_5)

sub1_pulling_features_5 = feature_space(sub1_pulling_features,features_remove_5)
sub2_pulling_features_5 = feature_space(sub2_pulling_features,features_remove_5)
sub3_pulling_features_5 = feature_space(sub3_pulling_features,features_remove_5)
sub4_pulling_features_5 = feature_space(sub3_pulling_features,features_remove_5)

sub1_punching_features_5 = feature_space(sub1_punching_features,features_remove_5)
sub2_punching_features_5 = feature_space(sub2_punching_features,features_remove_5)
sub3_punching_features_5 = feature_space(sub3_punching_features,features_remove_5)
sub4_punching_features_5 = feature_space(sub3_punching_features,features_remove_5)

sub1_pushing_features_5 = feature_space(sub1_pushing_features,features_remove_5)
sub2_pushing_features_5 = feature_space(sub2_pushing_features,features_remove_5)
sub3_pushing_features_5 = feature_space(sub3_pushing_features,features_remove_5)
sub4_pushing_features_5 = feature_space(sub3_pushing_features,features_remove_5)

sub1_sidekicking_features_5 = feature_space(sub1_sidekicking_features,features_remove_5)
sub2_sidekicking_features_5 = feature_space(sub2_sidekicking_features,features_remove_5)
sub3_sidekicking_features_5 = feature_space(sub3_sidekicking_features,features_remove_5)
sub4_sidekicking_features_5 = feature_space(sub3_sidekicking_features,features_remove_5)

sub1_slapping_features_5 = feature_space(sub1_slapping_features,features_remove_5)
sub2_slapping_features_5 = feature_space(sub2_slapping_features,features_remove_5)
sub3_slapping_features_5 = feature_space(sub3_slapping_features,features_remove_5)
sub4_slapping_features_5 = feature_space(sub3_slapping_features,features_remove_5)

sub1_hugging_features_5 = feature_space(sub1_hugging_features,features_remove_5)
sub2_hugging_features_5 = feature_space(sub2_hugging_features,features_remove_5)
sub3_hugging_features_5 = feature_space(sub3_hugging_features,features_remove_5)
sub4_hugging_features_5 = feature_space(sub3_hugging_features,features_remove_5)

sub1_jumping_features_5 = feature_space(sub1_jumping_features,features_remove_5)
sub2_jumping_features_5 = feature_space(sub2_jumping_features,features_remove_5)
sub3_jumping_features_5 = feature_space(sub3_jumping_features,features_remove_5)
sub4_jumping_features_5 = feature_space(sub3_jumping_features,features_remove_5)

sub1_running_features_5 = feature_space(sub1_running_features,features_remove_5)
sub2_running_features_5 = feature_space(sub2_running_features,features_remove_5)
sub3_running_features_5 = feature_space(sub3_running_features,features_remove_5)
sub4_running_features_5 = feature_space(sub3_running_features,features_remove_5)

sub1_seating_features_5 = feature_space(sub1_seating_features,features_remove_5)
sub2_seating_features_5 = feature_space(sub2_seating_features,features_remove_5)
sub3_seating_features_5 = feature_space(sub3_seating_features,features_remove_5)
sub4_seating_features_5 = feature_space(sub3_seating_features,features_remove_5)

sub1_standing_features_5 = feature_space(sub1_standing_features,features_remove_5)
sub2_standing_features_5 = feature_space(sub2_standing_features,features_remove_5)
sub3_standing_features_5 = feature_space(sub3_standing_features,features_remove_5)
sub4_standing_features_5 = feature_space(sub3_standing_features,features_remove_5)

sub1_walking_features_5 = feature_space(sub1_walking_features,features_remove_5)
sub2_walking_features_5 = feature_space(sub2_walking_features,features_remove_5)
sub3_walking_features_5 = feature_space(sub3_walking_features,features_remove_5)
sub4_walking_features_5 = feature_space(sub3_walking_features,features_remove_5)

sub1_waving_features_5 = feature_space(sub1_waving_features,features_remove_5)
sub2_waving_features_5 = feature_space(sub2_waving_features,features_remove_5)
sub3_waving_features_5 = feature_space(sub3_waving_features,features_remove_5)
sub4_waving_features_5 = feature_space(sub3_waving_features,features_remove_5)

# %%
subject1 = pd.concat([sub1_handshaking_features_5,sub1_punching_features_5,sub1_seating_features_5,sub1_standing_features_5,sub1_pushing_features_5,sub1_pulling_features_5,sub1_slapping_features_5,sub1_sidekicking_features_5,sub1_frontkicking_features_5,sub1_kneeing_features_5,sub1_hammering_features_5, sub1_hugging_features_5,sub1_headering_features_5,sub1_jumping_features_5,sub1_bowing_features_5,sub1_elbowing_features_5,sub1_running_features_5,sub1_walking_features_5,sub1_clapping_features_5,sub1_waving_features_5])
subject2 = pd.concat([sub2_handshaking_features_5,sub2_punching_features_5,sub2_seating_features_5,sub2_standing_features_5,sub2_pushing_features_5,sub2_pulling_features_5,sub2_slapping_features_5,sub2_sidekicking_features_5,sub2_frontkicking_features_5,sub2_kneeing_features_5,sub2_hammering_features_5, sub2_hugging_features_5,sub2_headering_features_5,sub2_jumping_features_5,sub2_bowing_features_5,sub2_elbowing_features_5,sub2_running_features_5,sub2_walking_features_5,sub2_clapping_features_5,sub2_waving_features_5])
subject3 = pd.concat([sub3_handshaking_features_5,sub3_punching_features_5,sub3_seating_features_5,sub3_standing_features_5,sub3_pushing_features_5,sub3_pulling_features_5,sub3_slapping_features_5,sub3_sidekicking_features_5,sub3_frontkicking_features_5,sub3_kneeing_features_5,sub3_hammering_features_5, sub3_hugging_features_5,sub3_headering_features_5,sub3_jumping_features_5,sub3_bowing_features_5,sub3_elbowing_features_5,sub3_running_features_5,sub3_walking_features_5,sub3_clapping_features_5,sub3_waving_features_5])
subject4 = pd.concat([sub4_handshaking_features_5,sub4_punching_features_5,sub4_seating_features_5,sub4_standing_features_5,sub4_pushing_features_5,sub4_pulling_features_5,sub4_slapping_features_5,sub4_sidekicking_features_5,sub4_frontkicking_features_5,sub4_kneeing_features_5,sub4_hammering_features_5, sub4_hugging_features_5,sub4_headering_features_5,sub4_jumping_features_5,sub4_bowing_features_5,sub4_elbowing_features_5,sub4_running_features_5,sub4_walking_features_5,sub4_clapping_features_5,sub4_waving_features_5])

# %%
#DROP ID column

subject1 = subject1.drop(['id'],axis=1)
subject2 = subject2.drop(['id'],axis=1)
subject3 = subject3.drop(['id'],axis=1)
subject4 = subject4.drop(['id'],axis=1)

subject1 = subject1.fillna(subject1.mean())
subject2 = subject2.fillna(subject2.mean())
subject3 = subject3.fillna(subject3.mean())
subject4 = subject4.fillna(subject4.mean())

# %%
Accuracy0_array,Accuracy1_array, Accuracy2_array, Accuracy3_array = crossvalidate(subject1,subject2,subject3,subject4)

# %%
N = 4
ind = np.arange(N)  # the x locations for the groups
width = 0.10       # the width of the bars

fig = plt.figure(figsize=(11,6))
plt.title('Normal vs. Aggressive Actions CV results')
ax = fig.add_subplot(111)

yvals = [Accuracy0_array[0], Accuracy0_array[1],Accuracy0_array[2], Accuracy0_array[3]]
rects1 = ax.bar(ind, yvals, width, color='skyblue')
zvals = [Accuracy1_array[0], Accuracy1_array[1],Accuracy1_array[2], Accuracy1_array[3]]
rects2 = ax.bar(ind+width, zvals, width, color='indianred')
kvals = [Accuracy2_array[0], Accuracy2_array[1],Accuracy2_array[2], Accuracy2_array[3]]
rects3 = ax.bar(ind+width*2, kvals, width, color='yellow')
xvals = [Accuracy3_array[0], Accuracy3_array[1],Accuracy3_array[2], Accuracy3_array[3]]
rects4 = ax.bar(ind+width*3, xvals, width, color='pink')

ax.set_ylabel('Accuracy at 0.5 threshold')
ax.set_xticks(ind+width)
ax.set_ylim([0,1.15])
ax.set_xticklabels( ('Leave Sub1/Fold 1', 'Leave Sub2/Fold 2', 'Leave Sub3/Fold 3', 'Leave Sub4/Fold 4') )
ax.legend( (rects1[0], rects2[0], rects3[0],rects4[0]), ('Default', 'Naive Bayes','Logistic Regression', 'Random Forests'), loc = 'upper right' )

# %%
display(subject1)

# %%
def feature_space(data,features_include):
    n,m = data.shape
    new_data = pd.DataFrame(data.loc[:,'label'])
    for i in range(0,m):
        for j in range(0,len(features_include)):
            if features_include[j] in data.columns.values[i]:
                column_name = data.columns.values[i]
                new_data[column_name] = data.loc[:,column_name]        
    new_data = new_data.drop(['label'], axis=1)
    new_data['label'] =data.loc[:,'label']
    return new_data

# %%
features_include_6 = ["quantiles","fft_coefficient","absolute_sum_of_changes","maximum","minimum","mean","median","Agg_linear_trend","abs_energy","mean_abs_change","autocorrelation","entropy","linear_trend","kurtosis"]

# %%
sub1_handshaking_features_6 = feature_space(sub1_handshaking_features,features_include_6)
sub2_handshaking_features_6 = feature_space(sub2_handshaking_features,features_include_6)
sub3_handshaking_features_6 = feature_space(sub3_handshaking_features,features_include_6)
sub4_handshaking_features_6 = feature_space(sub3_handshaking_features,features_include_6)

sub1_bowing_features_6 = feature_space(sub1_bowing_features,features_include_6)
sub2_bowing_features_6 = feature_space(sub2_bowing_features,features_include_6)
sub3_bowing_features_6 = feature_space(sub3_bowing_features,features_include_6)
sub4_bowing_features_6 = feature_space(sub3_bowing_features,features_include_6)

sub1_clapping_features_6 = feature_space(sub1_clapping_features,features_include_6)
sub2_clapping_features_6 = feature_space(sub2_clapping_features,features_include_6)
sub3_clapping_features_6 = feature_space(sub3_clapping_features,features_include_6)
sub4_clapping_features_6 = feature_space(sub3_clapping_features,features_include_6)

sub1_punching_features_6 = feature_space(sub1_punching_features,features_include_6)
sub2_punching_features_6 = feature_space(sub2_punching_features,features_include_6)
sub3_punching_features_6 = feature_space(sub3_punching_features,features_include_6)
sub4_punching_features_6 = feature_space(sub3_punching_features,features_include_6)

sub1_frontkicking_features_6 = feature_space(sub1_frontkicking_features,features_include_6)
sub2_frontkicking_features_6 = feature_space(sub2_frontkicking_features,features_include_6)
sub3_frontkicking_features_6 = feature_space(sub3_frontkicking_features,features_include_6)
sub4_frontkicking_features_6 = feature_space(sub3_frontkicking_features,features_include_6)

sub1_elbowing_features_6 = feature_space(sub1_elbowing_features,features_include_6)
sub2_elbowing_features_6 = feature_space(sub2_elbowing_features,features_include_6)
sub3_elbowing_features_6 = feature_space(sub3_elbowing_features,features_include_6)
sub4_elbowing_features_6 = feature_space(sub3_elbowing_features,features_include_6)

sub1_hammering_features_6 = feature_space(sub1_hammering_features,features_include_6)
sub2_hammering_features_6 = feature_space(sub2_hammering_features,features_include_6)
sub3_hammering_features_6 = feature_space(sub3_hammering_features,features_include_6)
sub4_hammering_features_6 = feature_space(sub3_hammering_features,features_include_6)

sub1_headering_features_6 = feature_space(sub1_headering_features,features_include_6)
sub2_headering_features_6 = feature_space(sub2_headering_features,features_include_6)
sub3_headering_features_6 = feature_space(sub3_headering_features,features_include_6)
sub4_headering_features_6 = feature_space(sub3_headering_features,features_include_6)

sub1_kneeing_features_6 = feature_space(sub1_kneeing_features,features_include_6)
sub2_kneeing_features_6 = feature_space(sub2_kneeing_features,features_include_6)
sub3_kneeing_features_6 = feature_space(sub3_kneeing_features,features_include_6)
sub4_kneeing_features_6 = feature_space(sub3_kneeing_features,features_include_6)

sub1_pulling_features_6 = feature_space(sub1_pulling_features,features_include_6)
sub2_pulling_features_6 = feature_space(sub2_pulling_features,features_include_6)
sub3_pulling_features_6 = feature_space(sub3_pulling_features,features_include_6)
sub4_pulling_features_6 = feature_space(sub3_pulling_features,features_include_6)

sub1_punching_features_6 = feature_space(sub1_punching_features,features_include_6)
sub2_punching_features_6 = feature_space(sub2_punching_features,features_include_6)
sub3_punching_features_6 = feature_space(sub3_punching_features,features_include_6)
sub4_punching_features_6 = feature_space(sub3_punching_features,features_include_6)

sub1_pushing_features_6 = feature_space(sub1_pushing_features,features_include_6)
sub2_pushing_features_6 = feature_space(sub2_pushing_features,features_include_6)
sub3_pushing_features_6 = feature_space(sub3_pushing_features,features_include_6)
sub4_pushing_features_6 = feature_space(sub3_pushing_features,features_include_6)

sub1_sidekicking_features_6 = feature_space(sub1_sidekicking_features,features_include_6)
sub2_sidekicking_features_6 = feature_space(sub2_sidekicking_features,features_include_6)
sub3_sidekicking_features_6 = feature_space(sub3_sidekicking_features,features_include_6)
sub4_sidekicking_features_6 = feature_space(sub3_sidekicking_features,features_include_6)

sub1_slapping_features_6 = feature_space(sub1_slapping_features,features_include_6)
sub2_slapping_features_6 = feature_space(sub2_slapping_features,features_include_6)
sub3_slapping_features_6 = feature_space(sub3_slapping_features,features_include_6)
sub4_slapping_features_6 = feature_space(sub3_slapping_features,features_include_6)

sub1_hugging_features_6 = feature_space(sub1_hugging_features,features_include_6)
sub2_hugging_features_6 = feature_space(sub2_hugging_features,features_include_6)
sub3_hugging_features_6 = feature_space(sub3_hugging_features,features_include_6)
sub4_hugging_features_6 = feature_space(sub3_hugging_features,features_include_6)

sub1_jumping_features_6 = feature_space(sub1_jumping_features,features_include_6)
sub2_jumping_features_6 = feature_space(sub2_jumping_features,features_include_6)
sub3_jumping_features_6 = feature_space(sub3_jumping_features,features_include_6)
sub4_jumping_features_6 = feature_space(sub3_jumping_features,features_include_6)

sub1_running_features_6 = feature_space(sub1_running_features,features_include_6)
sub2_running_features_6 = feature_space(sub2_running_features,features_include_6)
sub3_running_features_6 = feature_space(sub3_running_features,features_include_6)
sub4_running_features_6 = feature_space(sub3_running_features,features_include_6)

sub1_seating_features_6 = feature_space(sub1_seating_features,features_include_6)
sub2_seating_features_6 = feature_space(sub2_seating_features,features_include_6)
sub3_seating_features_6 = feature_space(sub3_seating_features,features_include_6)
sub4_seating_features_6 = feature_space(sub3_seating_features,features_include_6)

sub1_standing_features_6 = feature_space(sub1_standing_features,features_include_6)
sub2_standing_features_6 = feature_space(sub2_standing_features,features_include_6)
sub3_standing_features_6 = feature_space(sub3_standing_features,features_include_6)
sub4_standing_features_6 = feature_space(sub3_standing_features,features_include_6)

sub1_walking_features_6 = feature_space(sub1_walking_features,features_include_6)
sub2_walking_features_6 = feature_space(sub2_walking_features,features_include_6)
sub3_walking_features_6 = feature_space(sub3_walking_features,features_include_6)
sub4_walking_features_6 = feature_space(sub3_walking_features,features_include_6)

sub1_waving_features_6 = feature_space(sub1_waving_features,features_include_6)
sub2_waving_features_6 = feature_space(sub2_waving_features,features_include_6)
sub3_waving_features_6 = feature_space(sub3_waving_features,features_include_6)
sub4_waving_features_6 = feature_space(sub3_waving_features,features_include_6)

# %%
subject1 = pd.concat([sub1_handshaking_features_6,sub1_punching_features_6,sub1_seating_features_6,sub1_standing_features_6,sub1_pushing_features_6,sub1_pulling_features_6,sub1_slapping_features_6,sub1_sidekicking_features_6,sub1_frontkicking_features_6,sub1_kneeing_features_6,sub1_hammering_features_6, sub1_hugging_features_6,sub1_headering_features_6,sub1_jumping_features_6,sub1_bowing_features_6,sub1_elbowing_features_6,sub1_running_features_6,sub1_walking_features_6,sub1_clapping_features_6,sub1_waving_features_6])
subject2 = pd.concat([sub2_handshaking_features_6,sub2_punching_features_6,sub2_seating_features_6,sub2_standing_features_6,sub2_pushing_features_6,sub2_pulling_features_6,sub2_slapping_features_6,sub2_sidekicking_features_6,sub2_frontkicking_features_6,sub2_kneeing_features_6,sub2_hammering_features_6, sub2_hugging_features_6,sub2_headering_features_6,sub2_jumping_features_6,sub2_bowing_features_6,sub2_elbowing_features_6,sub2_running_features_6,sub2_walking_features_6,sub2_clapping_features_6,sub2_waving_features_6])
subject3 = pd.concat([sub3_handshaking_features_6,sub3_punching_features_6,sub3_seating_features_6,sub3_standing_features_6,sub3_pushing_features_6,sub3_pulling_features_6,sub3_slapping_features_6,sub3_sidekicking_features_6,sub3_frontkicking_features_6,sub3_kneeing_features_6,sub3_hammering_features_6, sub3_hugging_features_6,sub3_headering_features_6,sub3_jumping_features_6,sub3_bowing_features_6,sub3_elbowing_features_6,sub3_running_features_6,sub3_walking_features_6,sub3_clapping_features_6,sub3_waving_features_6])
subject4 = pd.concat([sub4_handshaking_features_6,sub4_punching_features_6,sub4_seating_features_6,sub4_standing_features_6,sub4_pushing_features_6,sub4_pulling_features_6,sub4_slapping_features_6,sub4_sidekicking_features_6,sub4_frontkicking_features_6,sub4_kneeing_features_6,sub4_hammering_features_6, sub4_hugging_features_6,sub4_headering_features_6,sub4_jumping_features_6,sub4_bowing_features_6,sub4_elbowing_features_6,sub4_running_features_6,sub4_walking_features_6,sub4_clapping_features_6,sub4_waving_features_6])

# %%
#DROP ID column

subject1 = subject1.fillna(subject1.mean())
subject2 = subject2.fillna(subject2.mean())
subject3 = subject3.fillna(subject3.mean())
subject4 = subject4.fillna(subject4.mean())

# %%
#Standardizing
X = subject1.copy()
labeled = list(X.loc[:,'label'])
X = X.drop(['label'],axis = 1)
scaler = preprocessing.StandardScaler().fit(X)
X_scaled = scaler.transform(X)                           
X_scaled = pd.DataFrame(X_scaled)
X_scaled.columns = X.columns
subject1 = X_scaled
subject1 = subject1.assign(label = labeled)

query = subject2.copy()
labeled = list(query.loc[:,'label'])
query = query.drop(['label'],axis = 1)
query_scaled = scaler.transform(query)
query_scaled = pd.DataFrame(query_scaled)
query_scaled.columns = query.columns
subject2 = query_scaled
subject2 = subject2.assign(label = labeled)


query = subject3.copy()
labeled = list(query.loc[:,'label'])
query = query.drop(['label'],axis = 1)
query_scaled = scaler.transform(query)
query_scaled = pd.DataFrame(query_scaled)
query_scaled.columns = query.columns
subject3 = query_scaled
subject3 = subject3.assign(label = labeled)


query = subject4.copy()
labeled = list(query.loc[:,'label'])
query = query.drop(['label'],axis = 1)
query_scaled = scaler.transform(query)
query_scaled = pd.DataFrame(query_scaled)
query_scaled.columns = query.columns
subject4 = query_scaled
subject4 = subject4.assign(label = labeled)

# %%
Accuracy0_array,Accuracy1_array, Accuracy2_array, Accuracy3_array = crossvalidate(subject1,subject2,subject3,subject4)
# Out:
# Leave subject 1 out
#
# Default model
#
#            |  PPos 	 PNeg 	 | Sums
# -------------------------------------
# actual pos |  888 	 0 	 | 888
# actual neg |  897 	 0 	 | 897
# -------------------------------------
# Sums       |  1785 	 0 	 | 1785
#    Accuracy  False Positive Rate  Precision  Recall  True Positive Rate
# 0  0.497479                  1.0   0.497479     1.0                 1.0
#
#
# Naives Bayes
#
#            |  PPos 	 PNeg 	 | Sums
# -------------------------------------
# actual pos |  753 	 135 	 | 888
# actual neg |  20 	 877 	 | 897
# -------------------------------------
# Sums       |  773 	 1012 	 | 1785
#    Accuracy  False Positive Rate  Precision    Recall  True Positive Rate
# 0  0.913165             0.022297   0.974127  0.847973            0.847973
#
#
# Logistic regression
#
#            |  PPos 	 PNeg 	 | Sums
# -------------------------------------
# actual pos |  832 	 56 	 | 888
# actual neg |  37 	 860 	 | 897
# ...

# %%
N = 4
ind = np.arange(N)  # the x locations for the groups
width = 0.10       # the width of the bars

fig = plt.figure(figsize=(11,6))
plt.title('Normal vs. Aggressive Actions CV results')
ax = fig.add_subplot(111)

yvals = [Accuracy0_array[0], Accuracy0_array[1],Accuracy0_array[2], Accuracy0_array[3]]
rects1 = ax.bar(ind, yvals, width, color='skyblue')
zvals = [Accuracy1_array[0], Accuracy1_array[1],Accuracy1_array[2], Accuracy1_array[3]]
rects2 = ax.bar(ind+width, zvals, width, color='indianred')
kvals = [Accuracy2_array[0], Accuracy2_array[1],Accuracy2_array[2], Accuracy2_array[3]]
rects3 = ax.bar(ind+width*2, kvals, width, color='yellow')
xvals = [Accuracy3_array[0], Accuracy3_array[1],Accuracy3_array[2], Accuracy3_array[3]]
rects4 = ax.bar(ind+width*3, xvals, width, color='pink')

ax.set_ylabel('Accuracy at 0.5 threshold')
ax.set_xticks(ind+width)
ax.set_ylim([0,1.15])
ax.set_xticklabels( ('Leave Sub1/Fold 1', 'Leave Sub2/Fold 2', 'Leave Sub3/Fold 3', 'Leave Sub4/Fold 4') )
ax.legend( (rects1[0], rects2[0], rects3[0],rects4[0]), ('Default', 'Naive Bayes','Logistic Regression', 'Random Forests'), loc = 'upper right' )

# %% [markdown]
# # PARAMETER TUNING

# %%
# Varying Logistic Regression

def get_pred_default(train,test):
    
    n,m = train.shape 
    X = train.iloc[:,:m-1]# get training input data
    query = test.iloc[:,:m-1]# get test input data
    
    #Get the frequently occuring category in training data
    arity_name, arity_freq = np.unique(train.iloc[:,m-1], return_counts = True)
    for i in range(0,len(arity_freq)):
        if(arity_freq[i] == max(arity_freq)):
            pred_def = i
            prob = float(arity_freq[i])/float(len(train))
    predicted_response = [pred_def]*len(test)
    predicted_prob = [prob]*len(test)
    return pd.DataFrame({'Predicted':predicted_response, 'Actual':test.iloc[:,m-1], 'Probability':predicted_prob})

def get_pred_nb(train,test):
    n,m = train.shape # number of rows and columns
    X = train.iloc[:,:m-1]# get training input data
    query = test.iloc[:,:m-1]# get test input data    
    gnb = GaussianNB()
    gnb.fit(X,train.iloc[:,m-1])
    predicted_response = gnb.predict(query)
    predicted_prob = gnb.predict_proba(query)[:, 1]
    return pd.DataFrame({'Predicted':predicted_response, 'Actual':test.iloc[:,m-1], 'Probability':predicted_prob})

def get_pred_logreg(train,test):
    n,m = train.shape # number of rows and columns
    X = train.iloc[:,:m-1]# get training input data
    y = train.iloc[:,m-1]
    query = test.iloc[:,:m-1]# get test input data    
    lm = LogisticRegression()
    lm.fit(X,y)
    predicted_response = lm.predict(query)
    predicted_prob = lm.predict_proba(query)[:, 1]
    return pd.DataFrame({'Predicted':predicted_response, 'Actual':test.iloc[:,m-1], 'Probability':predicted_prob})

def get_pred_rf(train,test):
    n,m = train.shape # number of rows and columns
    X = train.iloc[:,:m-1]# get training input data
    y = train.iloc[:,m-1]
    query = test.iloc[:,:m-1]    
    rf = RandomForestClassifier(n_estimators = 25)
    rf.fit(X,y)
    predicted_response = rf.predict(query)
    predicted_prob = rf.predict_proba(query)[:, 1]
    return pd.DataFrame({'Predicted':predicted_response, 'Actual':test.iloc[:,m-1], 'Probability':predicted_prob})

# %%
Accuracy0_array,Accuracy1_array, Accuracy2_array, Accuracy3_array = crossvalidate(subject1,subject2,subject3,subject4)
# Out:
# Leave subject 1 out
#
# Default model
#
#            |  PPos 	 PNeg 	 | Sums
# -------------------------------------
# actual pos |  888 	 0 	 | 888
# actual neg |  897 	 0 	 | 897
# -------------------------------------
# Sums       |  1785 	 0 	 | 1785
#    Accuracy  False Positive Rate  Precision  Recall  True Positive Rate
# 0  0.497479                  1.0   0.497479     1.0                 1.0
#
#
# Naives Bayes
#
#            |  PPos 	 PNeg 	 | Sums
# -------------------------------------
# actual pos |  753 	 135 	 | 888
# actual neg |  20 	 877 	 | 897
# -------------------------------------
# Sums       |  773 	 1012 	 | 1785
#    Accuracy  False Positive Rate  Precision    Recall  True Positive Rate
# 0  0.913165             0.022297   0.974127  0.847973            0.847973
#
#
# Logistic regression
#
#            |  PPos 	 PNeg 	 | Sums
# -------------------------------------
# actual pos |  832 	 56 	 | 888
# actual neg |  37 	 860 	 | 897
# ...

# %%
sub1_handshaking_features_6

# %%
rf = RandomForestClassifier(n_estimators = 100)
rf.fit(X,y)
feature_importances = pd.DataFrame(rf.feature_importances_,
                                   index = X.columns,
                                    columns=['importance']).sort_values('importance', ascending=False)
display(feature_importances)

# %% [markdown]
# ## Feature Visualization

# %%
subject1_normal = pd.concat([sub1_handshaking_features_5,sub1_seating_features_5,sub1_standing_features_5,sub1_hugging_features_5,sub1_jumping_features_5,sub1_bowing_features_5,sub1_running_features_5,sub1_walking_features_5,sub1_clapping_features_5,sub1_waving_features_5])
subject1_aggressive = pd.concat([sub1_punching_features_5,sub1_pushing_features_5,sub1_pulling_features_5,sub1_slapping_features_5,sub1_sidekicking_features_5,sub1_frontkicking_features_5,sub1_kneeing_features_5,sub1_hammering_features_5, sub1_headering_features_5,sub1_elbowing_features_5])
subject2_normal = pd.concat([sub2_handshaking_features_5,sub2_seating_features_5,sub2_standing_features_5,sub2_hugging_features_5,sub2_jumping_features_5,sub2_bowing_features_5,sub2_running_features_5,sub2_walking_features_5,sub2_clapping_features_5,sub2_waving_features_5])
subject2_aggressive = pd.concat([sub2_punching_features_5,sub2_pushing_features_5,sub2_pulling_features_5,sub2_slapping_features_5,sub2_sidekicking_features_5,sub2_frontkicking_features_5,sub2_kneeing_features_5,sub2_hammering_features_5, sub2_headering_features_5,sub2_elbowing_features_5])
subject3_normal = pd.concat([sub3_handshaking_features_5,sub3_seating_features_5,sub3_standing_features_5,sub3_hugging_features_5,sub3_jumping_features_5,sub3_bowing_features_5,sub3_running_features_5,sub3_walking_features_5,sub3_clapping_features_5,sub3_waving_features_5])
subject3_aggressive = pd.concat([sub3_punching_features_5,sub3_pushing_features_5,sub3_pulling_features_5,sub3_slapping_features_5,sub3_sidekicking_features_5,sub3_frontkicking_features_5,sub3_kneeing_features_5,sub3_hammering_features_5, sub3_headering_features_5,sub3_elbowing_features_5])
subject4_normal = pd.concat([sub4_handshaking_features_5,sub4_seating_features_5,sub4_standing_features_5,sub4_hugging_features_5,sub4_jumping_features_5,sub4_bowing_features_5,sub4_running_features_5,sub4_walking_features_5,sub4_clapping_features_5,sub4_waving_features_5])
subject4_aggressive = pd.concat([sub4_punching_features_5,sub4_pushing_features_5,sub4_pulling_features_5,sub4_slapping_features_5,sub4_sidekicking_features_5,sub4_frontkicking_features_5,sub4_kneeing_features_5,sub4_hammering_features_5, sub4_headering_features_5,sub4_elbowing_features_5])

data_aggressive = pd.concat([subject1_aggressive, subject1_aggressive, subject1_aggressive, subject1_aggressive])
data_normal = pd.concat([subject1_normal, subject1_normal, subject1_normal, subject1_normal])

# %%
R_Bic_abs_energy_aggressive = np.mean(data_aggressive['R-Bic__abs_energy'])
R_Tri_abs_energy_aggressive = np.mean(data_aggressive['R-Tri__abs_energy'])
L_Bic_abs_energy_aggressive = np.mean(data_aggressive['L-Bic__abs_energy'])
L_Tri_abs_energy_aggressive = np.mean(data_aggressive['L-Tri__abs_energy'])
R_Thi_abs_energy_aggressive = np.mean(data_aggressive['R-Thi__abs_energy'])
R_Ham_abs_energy_aggressive = np.mean(data_aggressive['R-Ham__abs_energy'])
L_Thi_abs_energy_aggressive = np.mean(data_aggressive['L-Thi__abs_energy'])
L_Ham_abs_energy_aggressive = np.mean(data_aggressive['L-Ham__abs_energy'])

# %%
R_Bic_abs_energy_normal = np.mean(data_normal['R-Bic__abs_energy'])
R_Tri_abs_energy_normal = np.mean(data_normal['R-Tri__abs_energy'])
L_Bic_abs_energy_normal = np.mean(data_normal['L-Bic__abs_energy'])
L_Tri_abs_energy_normal = np.mean(data_normal['L-Tri__abs_energy'])
R_Thi_abs_energy_normal = np.mean(data_normal['R-Thi__abs_energy'])
R_Ham_abs_energy_normal = np.mean(data_normal['R-Ham__abs_energy'])
L_Thi_abs_energy_normal = np.mean(data_normal['L-Thi__abs_energy'])
L_Ham_abs_energy_normal = np.mean(data_normal['L-Ham__abs_energy'])

# %%
N = 8
ind = np.arange(N)  # the x locations for the groups
width = 0.30      # the width of the bars

fig = plt.figure(figsize=(11,6))
plt.title('Absolute Energy of Normal vs. Aggressive Actions')
ax = fig.add_subplot(111)

yvals = [R_Bic_abs_energy_normal, R_Tri_abs_energy_normal,L_Bic_abs_energy_normal, L_Tri_abs_energy_normal,R_Thi_abs_energy_normal,R_Ham_abs_energy_normal,L_Thi_abs_energy_normal,L_Ham_abs_energy_normal]
rects1 = ax.bar(ind, yvals, width, color='skyblue')
zvals = [R_Bic_abs_energy_aggressive, R_Tri_abs_energy_aggressive,L_Bic_abs_energy_aggressive, L_Tri_abs_energy_aggressive,R_Thi_abs_energy_aggressive,R_Ham_abs_energy_aggressive,L_Thi_abs_energy_aggressive,L_Ham_abs_energy_aggressive]
rects2 = ax.bar(ind+width, zvals, width, color='indianred')

ax.set_xticks(ind+width)
#ax.set_ylim([0,1.15])
ax.set_xticklabels( ('R-Bic', 'R-Tri', 'L-Bic', 'L-Tri','R-Thi','R-Ham','L-Thi','L-Ham') )
ax.legend( (rects1[0], rects2[0]), ('Normal', 'Aggressive'), loc = 'upper right' )

# %%
R_Bic_mean_aggressive = np.mean(data_aggressive['R-Bic__mean'])
R_Tri_mean_aggressive = np.mean(data_aggressive['R-Tri__mean'])
L_Bic_mean_aggressive = np.mean(data_aggressive['L-Bic__mean'])
L_Tri_mean_aggressive = np.mean(data_aggressive['L-Tri__mean'])
R_Thi_mean_aggressive = np.mean(data_aggressive['R-Thi__mean'])
R_Ham_mean_aggressive = np.mean(data_aggressive['R-Ham__mean'])
L_Thi_mean_aggressive = np.mean(data_aggressive['L-Thi__mean'])
L_Ham_mean_aggressive = np.mean(data_aggressive['L-Ham__mean'])

# %%
R_Bic_mean_normal = np.mean(data_normal['R-Bic__mean'])
R_Tri_mean_normal = np.mean(data_normal['R-Tri__mean'])
L_Bic_mean_normal = np.mean(data_normal['L-Bic__mean'])
L_Tri_mean_normal = np.mean(data_normal['L-Tri__mean'])
R_Thi_mean_normal = np.mean(data_normal['R-Thi__mean'])
R_Ham_mean_normal = np.mean(data_normal['R-Ham__mean'])
L_Thi_mean_normal = np.mean(data_normal['L-Thi__mean'])
L_Ham_mean_normal = np.mean(data_normal['L-Ham__mean'])

# %%
N = 8
ind = np.arange(N)  # the x locations for the groups
width = 0.30      # the width of the bars

fig = plt.figure(figsize=(11,6))
plt.title('Mean of Normal vs. Aggressive Actions')
ax = fig.add_subplot(111)

yvals = [R_Bic_mean_normal, R_Tri_mean_normal,L_Bic_mean_normal, L_Tri_mean_normal,R_Thi_mean_normal,R_Ham_mean_normal,L_Thi_mean_normal,L_Ham_mean_normal]
rects1 = ax.bar(ind, yvals, width, color='skyblue')
zvals = [R_Bic_mean_aggressive, R_Tri_mean_aggressive,L_Bic_mean_aggressive, L_Tri_mean_aggressive,R_Thi_mean_aggressive,R_Ham_mean_aggressive,L_Thi_mean_aggressive,L_Ham_mean_aggressive]
rects2 = ax.bar(ind+width, zvals, width, color='indianred')

ax.set_xticks(ind+width)
#ax.set_ylim([0,1.15])
ax.set_xticklabels( ('R-Bic', 'R-Tri', 'L-Bic', 'L-Tri','R-Thi','R-Ham','L-Thi','L-Ham') )
ax.legend( (rects1[0], rects2[0]), ('Normal', 'Aggressive'), loc = 'upper right' )

# %%
R_Bic_variance_aggressive = np.mean(data_aggressive['R-Bic__variance'])
R_Tri_variance_aggressive = np.mean(data_aggressive['R-Tri__variance'])
L_Bic_variance_aggressive = np.mean(data_aggressive['L-Bic__variance'])
L_Tri_variance_aggressive = np.mean(data_aggressive['L-Tri__variance'])
R_Thi_variance_aggressive = np.mean(data_aggressive['R-Thi__variance'])
R_Ham_variance_aggressive = np.mean(data_aggressive['R-Ham__variance'])
L_Thi_variance_aggressive = np.mean(data_aggressive['L-Thi__variance'])
L_Ham_variance_aggressive = np.mean(data_aggressive['L-Ham__variance'])

# %%
R_Bic_mean_normal = np.mean(data_normal['R-Bic__mean'])
R_Tri_mean_normal = np.mean(data_normal['R-Tri__mean'])
L_Bic_mean_normal = np.mean(data_normal['L-Bic__mean'])
L_Tri_mean_normal = np.mean(data_normal['L-Tri__mean'])
R_Thi_mean_normal = np.mean(data_normal['R-Thi__mean'])
R_Ham_mean_normal = np.mean(data_normal['R-Ham__mean'])
L_Thi_mean_normal = np.mean(data_normal['L-Thi__mean'])
L_Ham_mean_normal = np.mean(data_normal['L-Ham__mean'])

# %%
N = 8
ind = np.arange(N)  # the x locations for the groups
width = 0.30      # the width of the bars

fig = plt.figure(figsize=(11,6))
plt.title('Variance of Normal vs. Aggressive Actions')
ax = fig.add_subplot(111)

yvals = [R_Bic_variance_normal, R_Tri_variance_normal,L_Bic_variance_normal, L_Tri_variance_normal,R_Thi_variance_normal,R_Ham_variance_normal,L_Thi_variance_normal,L_Ham_variance_normal]
rects1 = ax.bar(ind, yvals, width, color='skyblue')
zvals = [R_Bic_variance_aggressive, R_Tri_variance_aggressive,L_Bic_variance_aggressive, L_Tri_variance_aggressive,R_Thi_variance_aggressive,R_Ham_variance_aggressive,L_Thi_variance_aggressive,L_Ham_variance_aggressive]
rects2 = ax.bar(ind+width, zvals, width, color='indianred')

ax.set_xticks(ind+width)
#ax.set_ylim([0,1.15])
ax.set_xticklabels( ('R-Bic', 'R-Tri', 'L-Bic', 'L-Tri','R-Thi','R-Ham','L-Thi','L-Ham') )
ax.legend( (rects1[0], rects2[0]), ('Normal', 'Aggressive'), loc = 'upper right' )

# %%
R_Bic_absolute_sum_of_changes_normal = np.mean(data_normal['R-Bic__absolute_sum_of_changes'])
R_Tri_absolute_sum_of_changes_normal = np.mean(data_normal['R-Tri__absolute_sum_of_changes'])
L_Bic_absolute_sum_of_changes_normal = np.mean(data_normal['L-Bic__absolute_sum_of_changes'])
L_Tri_absolute_sum_of_changes_normal = np.mean(data_normal['L-Tri__absolute_sum_of_changes'])
R_Thi_absolute_sum_of_changes_normal = np.mean(data_normal['R-Thi__absolute_sum_of_changes'])
R_Ham_absolute_sum_of_changes_normal = np.mean(data_normal['R-Ham__absolute_sum_of_changes'])
L_Thi_absolute_sum_of_changes_normal = np.mean(data_normal['L-Thi__absolute_sum_of_changes'])
L_Ham_absolute_sum_of_changes_normal = np.mean(data_normal['L-Ham__absolute_sum_of_changes'])

# %%
R_Bic_absolute_sum_of_changes_aggressive = np.mean(data_aggressive['R-Bic__absolute_sum_of_changes'])
R_Tri_absolute_sum_of_changes_aggressive = np.mean(data_aggressive['R-Tri__absolute_sum_of_changes'])
L_Bic_absolute_sum_of_changes_aggressive = np.mean(data_aggressive['L-Bic__absolute_sum_of_changes'])
L_Tri_absolute_sum_of_changes_aggressive = np.mean(data_aggressive['L-Tri__absolute_sum_of_changes'])
R_Thi_absolute_sum_of_changes_aggressive = np.mean(data_aggressive['R-Thi__absolute_sum_of_changes'])
R_Ham_absolute_sum_of_changes_aggressive = np.mean(data_aggressive['R-Ham__absolute_sum_of_changes'])
L_Thi_absolute_sum_of_changes_aggressive = np.mean(data_aggressive['L-Thi__absolute_sum_of_changes'])
L_Ham_absolute_sum_of_changes_aggressive = np.mean(data_aggressive['L-Ham__absolute_sum_of_changes'])

# %%
N = 8
ind = np.arange(N)  # the x locations for the groups
width = 0.30      # the width of the bars

fig = plt.figure(figsize=(11,6))
plt.title('Absolute sum of changes of Normal vs. Aggressive Actions')
ax = fig.add_subplot(111)

yvals = [R_Bic_absolute_sum_of_changes_normal, R_Tri_absolute_sum_of_changes_normal,L_Bic_absolute_sum_of_changes_normal, L_Tri_absolute_sum_of_changes_normal,R_Thi_absolute_sum_of_changes_normal,R_Ham_absolute_sum_of_changes_normal,L_Thi_absolute_sum_of_changes_normal,L_Ham_absolute_sum_of_changes_normal]
rects1 = ax.bar(ind, yvals, width, color='skyblue')
zvals = [R_Bic_absolute_sum_of_changes_aggressive, R_Tri_absolute_sum_of_changes_aggressive,L_Bic_absolute_sum_of_changes_aggressive, L_Tri_absolute_sum_of_changes_aggressive,R_Thi_absolute_sum_of_changes_aggressive,R_Ham_absolute_sum_of_changes_aggressive,L_Thi_absolute_sum_of_changes_aggressive,L_Ham_absolute_sum_of_changes_aggressive]
rects2 = ax.bar(ind+width, zvals, width, color='indianred')

ax.set_xticks(ind+width)
#ax.set_ylim([0,1.15])
ax.set_xticklabels( ('R-Bic', 'R-Tri', 'L-Bic', 'L-Tri','R-Thi','R-Ham','L-Thi','L-Ham') )
ax.legend( (rects1[0], rects2[0]), ('Normal', 'Aggressive'), loc = 'upper right' )

# %% [markdown]
# ________________________________________________________________________
